# %% [markdown]
# - https://www.kdnuggets.com/2018/11/keras-long-short-term-memory-lstm-model-predict-stock-prices.html
# - https://towardsdatascience.com/time-series-analysis-visualization-forecasting-with-lstm-77a905180eba
# - https://machinelearningmastery.com/learning-curves-for-diagnosing-machine-learning-model-performance/
#
#
# - https://machinelearningmastery.com/diagnose-overfitting-underfitting-lstm-models/
# - https://machinelearningmastery.com/how-to-calculate-precision-recall-f1-and-more-for-deep-learning-models/
# - https://machinelearningmastery.com/metrics-evaluate-machine-learning-algorithms-python/
#
#
# - https://machinelearningmastery.com/time-series-forecasting-long-short-term-memory-network-python/
# - https://machinelearningmastery.com/multivariate-time-series-forecasting-lstms-keras/

# %%
# Exemplo completo

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import random
from statistics import mean, stdev, median
from scipy.stats import friedmanchisquare
from prettytable import PrettyTable

import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
#from keras.callbacks import EarlyStopping

# Configura os parâmetros do Matplotlib
# %matplotlib inline

plt.rcParams.update({'font.size': 20, 
                     'figure.figsize': (10, 8),
                     'figure.dpi': 90,
                     'savefig.dpi': 300,
                     'axes.grid': True,
                     'axes.axisbelow': True, 
                     'grid.color': 'k', 
                     'grid.linestyle': ':', 
                     'grid.linewidth': 0.5,
                     'grid.alpha': 0.5})



# Garante a reprodutibilidade com o Keras
np.random.seed(1)
tf.compat.v1.set_random_seed(2)

# ----------------------------------------------

# Converte as séries em aprendizado supervisionado
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
      
    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()
    
    # Sequência de entrada (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    
    # Sequência de predição (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    
    # Coloca tudo junto
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    
    # Remove as linhas com valores NaN
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# ----------------------------------------------

# Carrega os dados
df = pd.read_csv('data/covid19-atributo-valor.csv', header=0, index_col=0)

# Usar termos relativos
termos_relativos = False

# Carrega os dados
if termos_relativos == True:
    
    # Cria uma coluna, transformando os casos em relativos
    df['Casos Relativos'] = df.groupby('Código do País')['Casos Confirmados'].transform(lambda x: x / x.sum())
    
    # Colunas utilizadas, selecionadas de acordo com o método Wrapper    
    cols = [
        'Casos Relativos', 
        'PIB 2019', 
        'População', 
        'Área (Km/2)', 
        'Taxa de Fertilidade', 
        'Média de Idade', 
        'Total de Leitos Hospitalares', 
        'Temperatura Média (Janeiro - Março)',
    ]

else:
    
    # Remove os casos confirmados < 0
    df = df[df['Casos Confirmados'] > 0].cumsum()

    # Teste somente para o Brasil - 24
    #df = df[df['Código do País'] == 24]

    # Colunas utilizadas, selecionadas de acordo com o método Wrapper  
    cols = [
        'Casos Confirmados', 
        'PIB 2019', 
        'População', 
        'Área (Km/2)', 
        'Taxa de Fertilidade', 
        'Média de Idade', 
        'Total de Leitos Hospitalares', 
        'Temperatura Média (Janeiro - Março)',
    ]
    
    # Menores valores... teste
    cols1 = [
        'Casos Confirmados',
        #'Código do País',
        #'Latitude',
        #'Longitude',
        #'PIB 2019',
        #'População',
        #'População Urbana',
        #'Área (Km/2)',
        #'Densidade (Km/2)',
        'Taxa de Fertilidade',
        'Média de Idade',
        'Taxa de Fumantes',
        'Taxa de Mortalidade por Doenças Pulmonares',
        'Total de Leitos Hospitalares',
        #'Temperatura Média (Janeiro - Março)',
        #'Taxa de Umidade (Janeiro - Março)',
    ]
    
    # Menores valores... teste
    cols2 = [
        'Casos Confirmados',
        #'Código do País',
        'Latitude',
        'Longitude',
        'PIB 2019',
        'População',
        'População Urbana',
        'Área (Km/2)',
        'Densidade (Km/2)',
        'Taxa de Fertilidade',
        'Média de Idade',
        'Taxa de Fumantes',
        'Taxa de Mortalidade por Doenças Pulmonares',
        'Total de Leitos Hospitalares',
        'Temperatura Média (Janeiro - Março)',
        'Taxa de Umidade (Janeiro - Março)',
    ]
    
# Seleciona somente os dados das colunas desejadas
dados = df[cols]

print("\n")
print("-" * 100)
print("Predição dos Casos Confirmados de COVID-19 Utilizando Redes LSTM")
print("-" * 100)
print(f"\nAtributo alvo: {cols[0]}")
print(f"\nFeatures utilizados:\n")

for i,c in enumerate(cols[1:]):
    print(f"{i+1}. {c}")
    
print("\n")

# ----------------------------------------------

# Obtém os valores de cada coluna
values = dados.values

# Normaliza os valores
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)

# Determina o número de colunas que serão utilizadas (features)
N_COLS = len(cols) - 1
n_features = N_COLS + 1

# Porcentagem utilizada para gerar o conjunto de treinamento
per_train = 0.8

# Lista com os números de atrasos (delta t)
#n_atrasos = [1, 3, 7]
n_atrasos = [1, 3, 7, 15, 30, 60]

# ----------------------------------------------

# Controla a exibição do arquivo reestruturado
exibir_colunas = False

print("-" * 100)

print("\nAplicação da LSTM...\n")
      
print(f"Deltas: {n_atrasos}\n")

# Lista para armazenar os valores obtidos para a predição (delta, MSE, inv_yhat)
inv_yhat_list = []

# Loop para aplicação da LSTM
for delta in n_atrasos:
    
    print("." * 100)
    print("\n")
    print(f"* DELTA: {delta}\n")
    
    # Lista para armazenar os valores do MSE e da predição, para o delta atual
    delta_list = []
    
    print("=> 1. Reestruturando o conjunto de dados para o formato adequado...\n")
    
    # Estrutura no formato de aprendizado supervisionado
    reframed = series_to_supervised(scaled, delta, 1)
    print(f"Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: {reframed.shape}")
    #print("\n")
    
    if exibir_colunas == True:
        print(f"Colunas totais ({len(list(reframed.columns))}): {list(reframed.columns)}")
        print("\n")
        print("Reframed OLD:\n")
        print(reframed.head())
        #print("\n")
    
    # Recupera uma lista com as colunas que devem ser removidas
    colunas = list(reframed.columns)
    removidas = []

    for i in range(2,len(cols)+1):
        for coluna in colunas:
            if coluna == 'var' + str(i) + '(t)':
                removidas.append(coluna)


    # Remove as colunas que não queremos prever
    reframed.drop(removidas, axis=1, inplace=True)

    print(f"Colunas removidas ({len(removidas)}): {removidas}")
    #print("\n")
    print(f"Colunas utilizadas ({len(list(reframed.columns))}): {list(reframed.columns)}")
    print("\n")
    
    if exibir_colunas == True:
        print("Reframed NEW:\n")
        print(reframed.head())
        #print("\n")
        
    # ------------------------------------------
        
    print("=> 2. Preparando os conjuntos de treinamento e de teste...\n")
    
    # Obtém os valores de cada coluna que foi reestruturada
    values = reframed.values
    
    # Define o tamanho do conjunto de teste -> 80% dos dados
    train_size = int(per_train * len(values))
    
    print(f"Conjunto de treinamento gerado com {per_train * 100}% dos dados")
    
    # Separa os dados de treinamento e de testes
    train = values[:train_size, :]
    test = values[train_size:, :]
    
    # Define o total de amostras
    n_amostras = delta * n_features
    
    # Separa os dados de treinamento e de teste
    train_X, train_y = train[:, :n_amostras], train[:, -n_features]
    test_X, test_y = test[:, :n_amostras], test[:, -n_features]
    print(f"Dimensões do conjunto de treinamento: {train_X.shape}, {len(train_X)}, {train_y.shape}")

    # Reestrutura o input para o formato 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], delta, n_features))
    test_X = test_X.reshape((test_X.shape[0], delta, n_features))
    print(f"Dimensões dos conjuntos de treinamento e de teste: {train_X.shape}, {train_y.shape}, {test_X.shape}, {test_y.shape}")
    print("\n")

    # ------------------------------------------
    
    print("=> 3. Realizando o treinamento da rede neural...\n")
    
    # Configuração utilizada (1, 2 ou 3)
    configuracao = 1
    
    # Testes...
    configuracao = 4
    
    # # Define os parâmetros para a rede neural
    if configuracao == 1:
        neuronios_entrada = 4
        neuronios_saida = 1
        epocas = 10
        batch = 10
        dropout = 0.2
        otimizador = 'adam'
        estimativa_erro = 'mean_squared_error'
        
    elif configuracao == 2:
        neuronios_entrada = 20
        neuronios_saida = 1
        epocas = 100
        batch = 50
        dropout = 0.2
        otimizador = 'adam'
        estimativa_erro = 'mean_squared_error'  
        
    elif configuracao == 3:
        neuronios_entrada = 50
        neuronios_saida = 1
        epocas = 500
        batch = 72
        dropout = 0.2
        otimizador = 'adam'
        estimativa_erro = 'mean_squared_error'
        
    elif configuracao == 4:
        neuronios_entrada = 50
        neuronios_saida = 1
        epocas = 72
        batch = 72
        dropout = 0.2
        otimizador = 'adam'
        estimativa_erro = 'mean_squared_error'
        
    # ------------------------------------------
    
    # Cria o modelo
    model = Sequential()
    model.add(LSTM(neuronios_entrada, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dropout(dropout))
    model.add(Dense(neuronios_saida))
    model.compile(loss=estimativa_erro, optimizer=otimizador, metrics=['accuracy'])

    # Realiza o ajuste
    history = model.fit(train_X, train_y, 
                        epochs=epocas, 
                        batch_size=batch, 
                        validation_data=(test_X, test_y), 
                        #callbacks=[EarlyStopping(monitor='val_loss', patience=10)], 
                        verbose=2, 
                        shuffle=False)
    
    # Avalia a precisão do modelo
    #_, precisao_treino = model.evaluate(train_X, train_y, verbose=0)
    #_, precisao_teste = model.evaluate(test_X, test_y, verbose=0)
    #print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
    
    # ------------------------------------------

    # Exibe o resumo
    print("\nResumo do modelo\n")
    print(f"Configuração utilizada: {configuracao}")
    print(f"Time step (delta): {delta}")
    print(f"Total de features: {n_features}")
    print(f"Tamanho do conjunto de treino: {train_size}")
    print(f"Total de neurônios de entrada: {neuronios_entrada}")
    print(f"Total de neurônios de saída: {neuronios_saida}")
    print(f"Total de épocas (epochs): {epocas}")
    print(f"Tamanho do arquivo de lote (batch size): {batch}")
    print(f"Otimizador: {otimizador}")
    print(f"Estimador de erro: {estimativa_erro}")
    #print(f"Precisão do conjunto de treino: {100 * precisao_treino:.2f}%")
    #print(f"Precisão do conjunto de teste: {100 * precisao_teste:.2f}%")
    print("\n")
    model.summary()
    print("\n")

    # ------------------------------------------
    
    print("=> 4. Plotagem do histórico e da precisão...\n")
    
    #fig = plt.figure(figsize=(12, 6))
    
    #plt.subplot(1, 2, 1);
    plt.figure(figsize=(8, 6))
    plt.plot(history.history['loss'], label='Treino');
    plt.plot(history.history['val_loss'], label='Teste');
    plt.title(f"Gráfico de Desempenho para Delta: {delta}", fontsize=16, y=1.01);
    plt.ylabel('Perda', fontsize=16);
    plt.xlabel('Época', fontsize=16);
    plt.xticks(fontsize=14);
    plt.yticks(fontsize=14);
    plt.legend(bbox_to_anchor=(1.23,1.02), fontsize=13);
    #plt.legend(loc='upper right', fontsize=13);
    plt.show();
    
    #plt.subplot(1, 2, 2);
    #plt.plot(history.history['accuracy'], label='Treino');
    #plt.plot(history.history['val_accuracy'], label='Teste');
    #plt.title(f"Precisão do Modelo para Delta: {delta}", fontsize=16, y=1.01);
    #plt.ylabel('Precisão', fontsize=16);
    #plt.xlabel('Época', fontsize=16);
    #plt.xticks(fontsize=14);
    #plt.yticks(fontsize=14);
    #plt.show();
    
    #plt.tight_layout();
    #plt.show();
    
    # ------------------------------------------
    
    print("=> 5. Realizando a predição...\n")
    
    # Realiza uma predição
    #yhat = model.predict(test_X)
    #test_X = test_X.reshape((test_X.shape[0], delta * n_features))
    
    testPredict = model.predict(test_X)
    test_X = test_X.reshape((test_X.shape[0], delta * n_features))
    
    trainPredict = model.predict(train_X)
    train_X = train_X.reshape((train_X.shape[0], delta * n_features))


    # Inverte a escala - previsão
    #inv_yhat = np.concatenate((yhat, test_X[:, -N_COLS:]), axis=1)
    inv_yhat = np.concatenate((testPredict, test_X[:, -N_COLS:]), axis=1)
    inv_yhat = scaler.inverse_transform(inv_yhat)
    inv_yhat = inv_yhat[:,0]
    
     # Inverte a escala - treino
    inv_treino = np.concatenate((trainPredict, train_X[:, -N_COLS:]), axis=1)
    inv_treino = scaler.inverse_transform(inv_treino)
    inv_treino = inv_treino[:,0]

    # Inverte a escala - valor atual
    test_y = test_y.reshape((len(test_y), 1))
    inv_y = np.concatenate((test_y, test_X[:, -N_COLS:]), axis=1)
    inv_y = scaler.inverse_transform(inv_y)
    inv_y = inv_y[:,0]

    # Calcula o MSE
    #MSE = mean_squared_error(inv_y, inv_yhat)
    #print(f"\nErro Médio Quadrático (MSE): {MSE:.3f}")
    #print("\n") 
    
    trainScore = mean_squared_error(train_y, inv_treino)
    print('Train Score: %.2f' % (trainScore))

    testScore = mean_squared_error(inv_y, inv_yhat)
    print('Test Score: %.2f' % (testScore))
    print("\n")
    
    print("AQUI----")
    
    # ------------------------------------------
    
    # Armazena o delta na lista
    delta_list.append(delta)
    
    # Armazena o MSE na lista
    delta_list.append(MSE)
    
    # Calcula e armazena a média
    media = mean(inv_yhat)
    delta_list.append(media)
    
    # Calcula e armazena o desvio padrão
    desvio = stdev(inv_yhat)
    delta_list.append(desvio)
    
    # Precisão do conjunto de treinamento e de teste
    #delta_list.append(precisao_treino)
    #delta_list.append(precisao_teste)
    
    # Armazena o INV_YHAT na lista -> predições obtidas pelo modelo
    delta_list.append(inv_yhat)
    
    # Armazena todos os valores obtidos para a predição (delta, MSE, inv_yhat)
    inv_yhat_list.append(delta_list)
    
    # ------------------------------------------
    
    print("=> 6. Plotagem da predição...\n")
    
    print("\nGráfico da predição total\n\n")
    
    # Plotagem da predição total
    plt.figure(figsize=(8, 6))
    plt.title(f"Predição de Casos COVID-19, Delta: {delta}", fontsize=20, y=1.01);
    plt.plot(inv_y, color='k', label="Observação");
    plt.plot(inv_yhat, marker='o', color='r', alpha=0.4, label="Modelo");
    plt.ylabel('Casos Confirmados', fontsize=18);
    plt.xlabel('Time Step', fontsize=18);
    plt.xticks(fontsize=16);
    plt.yticks(fontsize=16);
    plt.legend(bbox_to_anchor=(1.3,1.02), fontsize=13);
    plt.show();   
    
    print("\n")
    
    # ------------------------------------------

    # Define alguns pontos 
    N = 100
    pred = 15
    
    print(f"Gráfico da predição para {N} pontos\n\n")

    # Plotagem da predição para esses pontos
    plt.figure(figsize=(8, 6))
    aa = [x for x in range(N)]
    plt.plot(aa, inv_y[:N], marker='o', color='k', alpha=0.4, label="Observação");
    plt.plot(aa, inv_yhat[:N], color='r', label="Modelo");
    plt.title(f"Predição de Casos COVID-19, Delta: {delta}", fontsize=18, y=1.01);
    plt.ylabel('Casos Confirmados', fontsize=18);
    plt.xlabel('Time Step', fontsize=18);
    plt.xticks(fontsize=16);
    plt.yticks(fontsize=16);
    plt.legend(bbox_to_anchor=(1.3,1.02), fontsize=13);
    plt.show();
    
    print("\n")
    
    # ------------------------------------------

    # Define alguns pontos
    N = N-pred

    observacao = inv_y[0:N,]
    modelo = inv_yhat[N:N + pred,]

    x1 = np.arange(len(observacao))
    x2 = np.arange(len(observacao), len(observacao) + pred)
    
    print(f"Gráfico da predição dos {pred} pontos finais\n\n")

    # Plotagem da predição dos pontos finais
    plt.figure(figsize=(8, 6))
    plt.plot(x1, inv_y[:N], marker='o', color='k', alpha=0.4, label="Observacao");
    plt.plot(inv_yhat[0:N + pred,], linewidth=1, color='r', label='Modelo Total');
    plt.plot(x2, modelo, color='b', linewidth=1, label='Modelo Final');
    plt.title(f"Predição de Casos COVID-19, Delta: {delta}", fontsize=18, y=1.01);
    plt.ylabel('Casos Confirmados', fontsize=18);
    plt.xlabel('Time Step', fontsize=18);
    plt.xticks(fontsize=16);
    plt.yticks(fontsize=16);
    plt.legend(bbox_to_anchor=(1.31,1.02), fontsize=13);
    plt.show();
    
# ----------------------------------------------

print("\n")
print("-" * 100)
print("\n")

# ----------------------------------------------

# Salva as predições
nome_arquivo = 'predicoes_' + str(configuracao) + '.csv'
print(f"=> Salvando as predições... -> {nome_arquivo}")

# Cabeçalho da tabela
linha = 'ID,Delta,Inv_Yhat\n'

# Monta a tabela com o resultado final -> ID, Delta, Inv_Yhat
for i, valor in enumerate(inv_yhat_list):
    #s = ','.join(map(str, valor[6]))
    s = ','.join(map(str, valor[4]))
    linha += f"{i+1}, {valor[0]}, {s}\n"

# Salva as predições em formato CSV
output = open(nome_arquivo, 'w')
output.write(linha)
output.close()

# ----------------------------------------------

# Exibe uma tabela os valores das estísticas
print(f"\n=> Exibindo as estatísticas para a configuração {configuracao}...\n")

# Cabeçalho da tabela
#resultado = PrettyTable(['ID', 'Delta', 'Média', 'Mediana', 'Desvio Padrão', 'MSE', 'Precisão - Treino', 'Precisão - Teste'], align='c')
resultado = PrettyTable(['ID', 'Delta', 'Média', 'Mediana', 'Desvio Padrão', 'MSE'], align='c')

# Monta a tabela com o resultado final
for i, valor in enumerate(inv_yhat_list):
    #resultado.add_row([i+1, valor[0], np.mean(valor[6]), median(valor[6]), valor[3], valor[1], valor[4], valor[5]])
    resultado.add_row([i+1, valor[0], np.mean(valor[4]), median(valor[4]), valor[3], valor[1]])

# Utiliza duas casas decimais para os números reais
resultado.float_format = '.2'

# Alinha à direita
resultado.align = 'r'

# Centraliza o ID e o Delta
resultado.align['ID'] = 'c'
resultado.align['Delta'] = 'c'

# Exibe os valores
print(resultado)

# ----------------------------------------------

# Salva as estatísticas
nome_arquivo = 'estatisticas_' + str(configuracao) + '.csv'
print(f"\n=> Salvando as estatísticas... -> {nome_arquivo}")

# Cabeçalho da tabela
#linha = 'ID,Delta,Média Global,Mediana,Desvio Padrão,MSE,Precisão-Treino,Precisão-Teste\n'
linha = 'ID,Delta,Média Global,Mediana,Desvio Padrão,MSE\n'

# Monta a tabela com o resultado final
for i, valor in enumerate(inv_yhat_list):
    #linha += f"{i+1},{valor[0]},{np.mean(valor[6]):.2f},{median(valor[6]):.2f},{valor[3]:.2f},{valor[1]:.2f},{valor[4]:.3f},{valor[5]:.3f}\n"
    linha += f"{i+1},{valor[0]},{np.mean(valor[4]):.2f},{median(valor[4]):.2f},{valor[3]:.2f},{valor[1]:.2f}\n"
    
# Salva as estatísticas em formato csv
output = open(nome_arquivo, 'w')
output.write(linha)
output.close()

# ----------------------------------------------

# Realiza o Teste de Friedman...
print("\n=> Realizando o Teste de Friedman...\n")

print("Hipótese 0: Os valores da predição para o número de casos confirmados de COVID-19 variam de acordo com o Delta T?\n")

# Separa as amostras -> yhat para cada delta
amostras = []
for i, valor in enumerate(inv_yhat_list):
    #amostras.append(valor[6])
    amostras.append(valor[4])
    
#print(f"Amostras:\n{amostras}\n")

# Encontra o tamanho da menor amostra
menor_amostra = 100000
for i in amostras:
    if len(i) < menor_amostra:
        menor_amostra = len(i)

# Gera uma lista com as amostras, considerando o tamanho da menor amostra
amostras = [amostra[0:menor_amostra] for amostra in amostras]

# Aplica o Teste de Friedman
stat, p = friedmanchisquare(*amostras)

print(f"Estatística: {stat:.3f}, p: {p:.3f}\n")

# Interpretação
print("Interpretação do resultado...\n")

alpha = 0.05

if p > alpha:
    print("* Mesma distribuição -> falha ao rejeitar a hipótese H0")
else:
    print("* Distribuições diferentes -> rejeita a hipótese H0")

# ----------------------------------------------

# Salva os valores para o Teste de Friedman
print(f"\n=> Exibindo o teste de Friedman para a configuração {configuracao}...\n")

# Cabeçalho da tabela
resultado = PrettyTable(['ID', 'Delta', 'Média', 'Mediana', 'Desvio Padrão', 'Friedman STAT', 'Friedman P'], align='c')

# Monta a tabela com o resultado final
for i, amostra in enumerate(amostras):
    resultado.add_row([i+1, n_atrasos[i], np.mean(amostra), median(amostra), stdev(amostra), stat, p])

# Utiliza duas casas decimais para os números reais
resultado.float_format = '.2'

# Alinha à direita
resultado.align = 'r'

# Centraliza o ID e o Delta
resultado.align['ID'] = 'c'
resultado.align['Delta'] = 'c'

# Exibe os valores
print(resultado)

# ----------------------------------------------

# Salva o teste de Friedman
nome_arquivo = 'friedman_' + str(configuracao) + '.csv'
print(f"\n=> Salvando o teste de Friedman... -> {nome_arquivo}")

# Cabeçalho da tabela
linha = 'ID,Delta,Média,Mediana,Desvio Padrão,Friedman STAT, Friedman P\n'

# Monta a tabela com o resultado final
for i, amostra in enumerate(amostras):
    linha += f"{i+1},{n_atrasos[i]},{np.mean(amostra):.2f},{median(amostra):.2f},{stdev(amostra):.2f},{stat:.2f},{p:.2f}\n"
    
# Salva as estatísticas em formato csv
output = open(nome_arquivo, 'w')
output.write(linha)
output.close()

# ----------------------------------------------

print("\n")
print("-" * 100)
print("Fim!")
print("-" * 100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Predição dos Casos Confirmados de COVID-19 Utilizando Redes LSTM
# ----------------------------------------------------------------------------------------------------
#
# Atributo alvo: Casos Confirmados
#
# Features utilizados:
#
# 1. PIB 2019
# 2. População
# 3. Área (Km/2)
# 4. Taxa de Fertilidade
# 5. Média de Idade
# 6. Total de Leitos Hospitalares
# 7. Temperatura Média (Janeiro - Março)
#
#
# ----------------------------------------------------------------------------------------------------
#
# Aplicação da LSTM...
#
# Deltas: [1, 3, 7, 15, 30, 60]
#
# ....................................................................................................
#
#
# * DELTA: 1
#
# => 1. Reestruturando o conjunto de dados para o formato adequado...
#
# Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: (7889, 16)
# Colunas removidas (7): ['var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)']
# Colunas utilizadas (9): ['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)']
#
#
# => 2. Preparando os conjuntos de treinamento e de teste...
#
# Conjunto de treinamento gerado com 80.0% dos dados
# Dimensões do conjunto de treinamento: (6311, 8), 6311, (6311,)
# Dimensões dos conjuntos de treinamento e de teste: (6311, 1, 8), (6311,), (1578, 1, 8), (1578,)
#
#
# => 3. Realizando o treinamento da rede neural...
#
# Train on 6311 samples, validate on 1578 samples
# Epoch 1/50
#  - 2s - loss: 0.0306 - accuracy: 1.5845e-04 - val_loss: 1.9426e-04 - val_accuracy: 0.0000e+00
# Epoch 2/50
#  - 1s - loss: 0.0050 - accuracy: 1.5845e-04 - val_loss: 5.7932e-05 - val_accuracy: 0.0000e+00
# Epoch 3/50
#  - 0s - loss: 0.0051 - accuracy: 1.5845e-04 - val_loss: 5.9926e-05 - val_accuracy: 0.0000e+00
# Epoch 4/50
#  - 0s - loss: 0.0046 - accuracy: 1.5845e-04 - val_loss: 2.0898e-05 - val_accuracy: 0.0000e+00
# Epoch 5/50
#  - 0s - loss: 0.0042 - accuracy: 1.5845e-04 - val_loss: 1.0575e-05 - val_accuracy: 0.0000e+00
# Epoch 6/50
#  - 1s - loss: 0.0041 - accuracy: 1.5845e-04 - val_loss: 3.0221e-05 - val_accuracy: 0.0000e+00
# Epoch 7/50
#  - 0s - loss: 0.0040 - accuracy: 1.5845e-04 - val_loss: 8.8898e-05 - val_accuracy: 0.0000e+00
# Epoch 8/50
#  - 0s - loss: 0.0039 - accuracy: 1.5845e-04 - val_loss: 5.8416e-06 - val_accuracy: 0.0000e+00
# Epoch 9/50
#  - 0s - loss: 0.0036 - accuracy: 1.5845e-04 - val_loss: 4.5674e-05 - val_accuracy: 0.0000e+00
# Epoch 10/50
#  - 0s - loss: 0.0036 - accuracy: 1.5845e-04 - val_loss: 2.3878e-04 - val_accuracy: 0.0000e+00
# Epoch 11/50
#  - 0s - loss: 0.0034 - accuracy: 1.5845e-04 - val_loss: 2.0760e-04 - val_accuracy: 0.0000e+00
# Epoch 12/50
#  - 0s - loss: 0.0034 - accuracy: 1.5845e-04 - val_loss: 1.2549e-04 - val_accuracy: 0.0000e+00
# Epoch 13/50
#  - 0s - loss: 0.0033 - accuracy: 1.5845e-04 - val_loss: 2.2980e-05 - val_accuracy: 0.0000e+00
# Epoch 14/50
#  - 0s - loss: 0.0031 - accuracy: 1.5845e-04 - val_loss: 1.4133e-04 - val_accuracy: 0.0000e+00
# Epoch 15/50
#  - 0s - loss: 0.0030 - accuracy: 1.5845e-04 - val_loss: 3.1039e-04 - val_accuracy: 0.0000e+00
# Epoch 16/50
#  - 0s - loss: 0.0030 - accuracy: 1.5845e-04 - val_loss: 4.3465e-05 - val_accuracy: 0.0000e+00
# Epoch 17/50
#  - 0s - loss: 0.0028 - accuracy: 1.5845e-04 - val_loss: 5.1838e-05 - val_accuracy: 0.0000e+00
# Epoch 18/50
#  - 0s - loss: 0.0028 - accuracy: 1.5845e-04 - val_loss: 1.3001e-05 - val_accuracy: 0.0000e+00
# Epoch 19/50
#  - 0s - loss: 0.0026 - accuracy: 1.5845e-04 - val_loss: 2.2521e-04 - val_accuracy: 0.0000e+00
# Epoch 20/50
#  - 0s - loss: 0.0027 - accuracy: 1.5845e-04 - val_loss: 9.9520e-05 - val_accuracy: 0.0000e+00
# Epoch 21/50
#  - 0s - loss: 0.0026 - accuracy: 1.5845e-04 - val_loss: 8.1457e-05 - val_accuracy: 0.0000e+00
# Epoch 22/50
#  - 0s - loss: 0.0025 - accuracy: 1.5845e-04 - val_loss: 4.3859e-05 - val_accuracy: 0.0000e+00
# Epoch 23/50
#  - 0s - loss: 0.0024 - accuracy: 1.5845e-04 - val_loss: 9.0090e-04 - val_accuracy: 0.0000e+00
# Epoch 24/50
#  - 0s - loss: 0.0023 - accuracy: 1.5845e-04 - val_loss: 4.5445e-04 - val_accuracy: 0.0000e+00
# Epoch 25/50
#  - 0s - loss: 0.0023 - accuracy: 1.5845e-04 - val_loss: 1.5071e-04 - val_accuracy: 0.0000e+00
# Epoch 26/50
#  - 0s - loss: 0.0022 - accuracy: 1.5845e-04 - val_loss: 2.7403e-04 - val_accuracy: 0.0000e+00
# Epoch 27/50
#  - 0s - loss: 0.0021 - accuracy: 1.5845e-04 - val_loss: 3.0655e-04 - val_accuracy: 0.0000e+00
# Epoch 28/50
#  - 0s - loss: 0.0020 - accuracy: 1.5845e-04 - val_loss: 9.0282e-05 - val_accuracy: 0.0000e+00
# Epoch 29/50
#  - 0s - loss: 0.0021 - accuracy: 1.5845e-04 - val_loss: 2.4652e-04 - val_accuracy: 0.0000e+00
# Epoch 30/50
#  - 0s - loss: 0.0020 - accuracy: 1.5845e-04 - val_loss: 2.3402e-04 - val_accuracy: 0.0000e+00
# Epoch 31/50
#  - 0s - loss: 0.0019 - accuracy: 1.5845e-04 - val_loss: 4.2707e-04 - val_accuracy: 0.0000e+00
# Epoch 32/50
#  - 0s - loss: 0.0018 - accuracy: 1.5845e-04 - val_loss: 6.4044e-04 - val_accuracy: 0.0000e+00
# Epoch 33/50
#  - 0s - loss: 0.0017 - accuracy: 1.5845e-04 - val_loss: 2.3195e-04 - val_accuracy: 0.0000e+00
# Epoch 34/50
#  - 0s - loss: 0.0018 - accuracy: 1.5845e-04 - val_loss: 8.9449e-05 - val_accuracy: 0.0000e+00
# Epoch 35/50
#  - 0s - loss: 0.0016 - accuracy: 1.5845e-04 - val_loss: 1.0376e-04 - val_accuracy: 0.0000e+00
# Epoch 36/50
#  - 0s - loss: 0.0016 - accuracy: 1.5845e-04 - val_loss: 6.5292e-04 - val_accuracy: 0.0000e+00
# Epoch 37/50
#  - 0s - loss: 0.0016 - accuracy: 1.5845e-04 - val_loss: 8.0613e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
#  - 0s - loss: 0.0015 - accuracy: 1.5845e-04 - val_loss: 2.7282e-04 - val_accuracy: 0.0000e+00
# Epoch 39/50
#  - 0s - loss: 0.0014 - accuracy: 1.5845e-04 - val_loss: 4.7332e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
#  - 0s - loss: 0.0013 - accuracy: 1.5845e-04 - val_loss: 8.8347e-04 - val_accuracy: 0.0000e+00
# Epoch 41/50
#  - 0s - loss: 0.0013 - accuracy: 1.5845e-04 - val_loss: 7.6615e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
#  - 0s - loss: 0.0013 - accuracy: 1.5845e-04 - val_loss: 7.4325e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
#  - 0s - loss: 0.0012 - accuracy: 1.5845e-04 - val_loss: 9.6115e-05 - val_accuracy: 0.0000e+00
# Epoch 44/50
#  - 0s - loss: 0.0012 - accuracy: 1.5845e-04 - val_loss: 5.3538e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
#  - 0s - loss: 0.0011 - accuracy: 1.5845e-04 - val_loss: 5.3406e-04 - val_accuracy: 0.0000e+00
# Epoch 46/50
#  - 0s - loss: 0.0010 - accuracy: 1.5845e-04 - val_loss: 7.9000e-04 - val_accuracy: 0.0000e+00
# Epoch 47/50
#  - 0s - loss: 9.8592e-04 - accuracy: 1.5845e-04 - val_loss: 4.2362e-04 - val_accuracy: 0.0000e+00
# Epoch 48/50
#  - 0s - loss: 9.8598e-04 - accuracy: 1.5845e-04 - val_loss: 5.9016e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
#  - 0s - loss: 8.4484e-04 - accuracy: 1.5845e-04 - val_loss: 3.1580e-04 - val_accuracy: 0.0000e+00
# Epoch 50/50
#  - 0s - loss: 8.6736e-04 - accuracy: 1.5845e-04 - val_loss: 1.0308e-04 - val_accuracy: 0.0000e+00
#
# Resumo do modelo
#
# Configuração utilizada: 4
# Time step (delta): 1
# Total de features: 8
# Tamanho do conjunto de treino: 6311
# Total de neurônios de entrada: 30
# Total de neurônios de saída: 1
# Total de épocas (epochs): 50
# Tamanho do arquivo de lote (batch size): 72
# Otimizador: adam
# Estimador de erro: mean_squared_error
#
#
# Model: "sequential_102"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_102 (LSTM)              (None, 30)                4680
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_102 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 4,711
# Trainable params: 4,711
# Non-trainable params: 0
# _________________________________________________________________
#
#
# => 4. Plotagem do histórico e da precisão...
# => 5. Realizando a predição...
#
# Train Score: 434615846996231.81
# Test Score: 111947968725.20
#
#
# AQUI----
# => 6. Plotagem da predição...
#
#
# Gráfico da predição total
# Gráfico da predição para 100 pontos
# Gráfico da predição dos 15 pontos finais
# ....................................................................................................
#
#
# * DELTA: 3
#
# => 1. Reestruturando o conjunto de dados para o formato adequado...
#
# Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: (7887, 32)
# Colunas removidas (7): ['var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)']
# Colunas utilizadas (25): ['var1(t-3)', 'var2(t-3)', 'var3(t-3)', 'var4(t-3)', 'var5(t-3)', 'var6(t-3)', 'var7(t-3)', 'var8(t-3)', 'var1(t-2)', 'var2(t-2)', 'var3(t-2)', 'var4(t-2)', 'var5(t-2)', 'var6(t-2)', 'var7(t-2)', 'var8(t-2)', 'var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)']
#
#
# => 2. Preparando os conjuntos de treinamento e de teste...
#
# Conjunto de treinamento gerado com 80.0% dos dados
# Dimensões do conjunto de treinamento: (6309, 24), 6309, (6309,)
# Dimensões dos conjuntos de treinamento e de teste: (6309, 3, 8), (6309,), (1578, 3, 8), (1578,)
#
#
# => 3. Realizando o treinamento da rede neural...
#
# Train on 6309 samples, validate on 1578 samples
# Epoch 1/50
#  - 1s - loss: 0.0183 - accuracy: 0.0000e+00 - val_loss: 4.6476e-06 - val_accuracy: 0.0000e+00
# Epoch 2/50
#  - 1s - loss: 0.0068 - accuracy: 0.0000e+00 - val_loss: 1.0228e-04 - val_accuracy: 0.0000e+00
# Epoch 3/50
#  - 1s - loss: 0.0049 - accuracy: 0.0000e+00 - val_loss: 4.9731e-06 - val_accuracy: 0.0000e+00
# Epoch 4/50
#  - 1s - loss: 0.0041 - accuracy: 0.0000e+00 - val_loss: 4.0320e-04 - val_accuracy: 0.0000e+00
# Epoch 5/50
#  - 1s - loss: 0.0036 - accuracy: 0.0000e+00 - val_loss: 6.4195e-05 - val_accuracy: 0.0000e+00
# Epoch 6/50
#  - 1s - loss: 0.0035 - accuracy: 0.0000e+00 - val_loss: 1.7305e-05 - val_accuracy: 0.0000e+00
# Epoch 7/50
#  - 1s - loss: 0.0035 - accuracy: 0.0000e+00 - val_loss: 7.1155e-05 - val_accuracy: 0.0000e+00
# Epoch 8/50
#  - 1s - loss: 0.0033 - accuracy: 0.0000e+00 - val_loss: 7.5984e-04 - val_accuracy: 0.0000e+00
# Epoch 9/50
#  - 1s - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 2.3284e-04 - val_accuracy: 0.0000e+00
# Epoch 10/50
#  - 1s - loss: 0.0030 - accuracy: 0.0000e+00 - val_loss: 3.3259e-05 - val_accuracy: 0.0000e+00
# Epoch 11/50
#  - 1s - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 1.1770e-04 - val_accuracy: 0.0000e+00
# Epoch 12/50
#  - 1s - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 5.2559e-05 - val_accuracy: 0.0000e+00
# Epoch 13/50
#  - 1s - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 3.6504e-04 - val_accuracy: 0.0000e+00
# Epoch 14/50
#  - 1s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 1.5010e-04 - val_accuracy: 0.0000e+00
# Epoch 15/50
#  - 1s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 6.4577e-05 - val_accuracy: 0.0000e+00
# Epoch 16/50
#  - 1s - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 3.5627e-04 - val_accuracy: 0.0000e+00
# Epoch 17/50
#  - 1s - loss: 0.0023 - accuracy: 0.0000e+00 - val_loss: 2.8058e-05 - val_accuracy: 0.0000e+00
# Epoch 18/50
#  - 1s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 6.1330e-04 - val_accuracy: 0.0000e+00
# Epoch 19/50
#  - 1s - loss: 0.0020 - accuracy: 0.0000e+00 - val_loss: 2.6622e-04 - val_accuracy: 0.0000e+00
# Epoch 20/50
#  - 1s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 21/50
#  - 1s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 2.1873e-04 - val_accuracy: 0.0000e+00
# Epoch 22/50
#  - 1s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 23/50
#  - 1s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 4.3445e-04 - val_accuracy: 0.0000e+00
# Epoch 24/50
#  - 1s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 5.2666e-05 - val_accuracy: 0.0000e+00
# Epoch 25/50
#  - 1s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 8.1600e-05 - val_accuracy: 0.0000e+00
# Epoch 26/50
#  - 1s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 7.0489e-06 - val_accuracy: 0.0000e+00
# Epoch 27/50
#  - 1s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 9.1335e-05 - val_accuracy: 0.0000e+00
# Epoch 28/50
#  - 1s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 3.6920e-04 - val_accuracy: 0.0000e+00
# Epoch 29/50
#  - 1s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 2.0238e-05 - val_accuracy: 0.0000e+00
# Epoch 30/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 6.2775e-05 - val_accuracy: 0.0000e+00
# Epoch 31/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 6.0809e-04 - val_accuracy: 0.0000e+00
# Epoch 32/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 5.9585e-05 - val_accuracy: 0.0000e+00
# Epoch 33/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 6.4799e-04 - val_accuracy: 0.0000e+00
# Epoch 34/50
#  - 1s - loss: 9.9126e-04 - accuracy: 0.0000e+00 - val_loss: 2.4750e-04 - val_accuracy: 0.0000e+00
# Epoch 35/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 3.2912e-05 - val_accuracy: 0.0000e+00
# Epoch 36/50
#  - 1s - loss: 9.4697e-04 - accuracy: 0.0000e+00 - val_loss: 4.0299e-04 - val_accuracy: 0.0000e+00
# Epoch 37/50
#  - 1s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 4.7348e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
#  - 1s - loss: 8.0389e-04 - accuracy: 0.0000e+00 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 39/50
#  - 1s - loss: 9.6091e-04 - accuracy: 0.0000e+00 - val_loss: 2.2370e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
#  - 1s - loss: 8.7799e-04 - accuracy: 0.0000e+00 - val_loss: 5.8761e-04 - val_accuracy: 0.0000e+00
# Epoch 41/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 1.0428e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
#  - 1s - loss: 7.9690e-04 - accuracy: 0.0000e+00 - val_loss: 1.9975e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
#  - 1s - loss: 9.2934e-04 - accuracy: 0.0000e+00 - val_loss: 4.2011e-04 - val_accuracy: 0.0000e+00
# Epoch 44/50
#  - 1s - loss: 7.9679e-04 - accuracy: 0.0000e+00 - val_loss: 3.5008e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
#  - 1s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 1.8306e-04 - val_accuracy: 0.0000e+00
# Epoch 46/50
#  - 1s - loss: 9.7210e-04 - accuracy: 0.0000e+00 - val_loss: 3.2893e-04 - val_accuracy: 0.0000e+00
# Epoch 47/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 2.9405e-04 - val_accuracy: 0.0000e+00
# Epoch 48/50
#  - 1s - loss: 8.3999e-04 - accuracy: 0.0000e+00 - val_loss: 3.0970e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
#  - 1s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 7.6712e-05 - val_accuracy: 0.0000e+00
# Epoch 50/50
#  - 1s - loss: 6.4823e-04 - accuracy: 0.0000e+00 - val_loss: 4.1431e-04 - val_accuracy: 0.0000e+00
#
# Resumo do modelo
#
# Configuração utilizada: 4
# Time step (delta): 3
# Total de features: 8
# Tamanho do conjunto de treino: 6309
# Total de neurônios de entrada: 30
# Total de neurônios de saída: 1
# Total de épocas (epochs): 50
# Tamanho do arquivo de lote (batch size): 72
# Otimizador: adam
# Estimador de erro: mean_squared_error
#
#
# Model: "sequential_103"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_103 (LSTM)              (None, 30)                4680
# _________________________________________________________________
# dropout_103 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_103 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 4,711
# Trainable params: 4,711
# Non-trainable params: 0
# _________________________________________________________________
#
#
# => 4. Plotagem do histórico e da precisão...
# => 5. Realizando a predição...
#
# Train Score: 444393206233180.19
# Test Score: 449949211424.58
#
#
# AQUI----
# => 6. Plotagem da predição...
#
#
# Gráfico da predição total
# Gráfico da predição para 100 pontos
# Gráfico da predição dos 15 pontos finais
# ....................................................................................................
#
#
# * DELTA: 7
#
# => 1. Reestruturando o conjunto de dados para o formato adequado...
#
# Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: (7883, 64)
# Colunas removidas (7): ['var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)']
# Colunas utilizadas (57): ['var1(t-7)', 'var2(t-7)', 'var3(t-7)', 'var4(t-7)', 'var5(t-7)', 'var6(t-7)', 'var7(t-7)', 'var8(t-7)', 'var1(t-6)', 'var2(t-6)', 'var3(t-6)', 'var4(t-6)', 'var5(t-6)', 'var6(t-6)', 'var7(t-6)', 'var8(t-6)', 'var1(t-5)', 'var2(t-5)', 'var3(t-5)', 'var4(t-5)', 'var5(t-5)', 'var6(t-5)', 'var7(t-5)', 'var8(t-5)', 'var1(t-4)', 'var2(t-4)', 'var3(t-4)', 'var4(t-4)', 'var5(t-4)', 'var6(t-4)', 'var7(t-4)', 'var8(t-4)', 'var1(t-3)', 'var2(t-3)', 'var3(t-3)', 'var4(t-3)', 'var5(t-3)', 'var6(t-3)', 'var7(t-3)', 'var8(t-3)', 'var1(t-2)', 'var2(t-2)', 'var3(t-2)', 'var4(t-2)', 'var5(t-2)', 'var6(t-2)', 'var7(t-2)', 'var8(t-2)', 'var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)']
#
#
# => 2. Preparando os conjuntos de treinamento e de teste...
#
# Conjunto de treinamento gerado com 80.0% dos dados
# Dimensões do conjunto de treinamento: (6306, 56), 6306, (6306,)
# Dimensões dos conjuntos de treinamento e de teste: (6306, 7, 8), (6306,), (1577, 7, 8), (1577,)
#
#
# => 3. Realizando o treinamento da rede neural...
#
# Train on 6306 samples, validate on 1577 samples
# Epoch 1/50
#  - 2s - loss: 0.0088 - accuracy: 0.0000e+00 - val_loss: 2.9741e-04 - val_accuracy: 0.0000e+00
# Epoch 2/50
#  - 1s - loss: 0.0048 - accuracy: 0.0000e+00 - val_loss: 5.8789e-05 - val_accuracy: 0.0000e+00
# Epoch 3/50
#  - 1s - loss: 0.0036 - accuracy: 0.0000e+00 - val_loss: 5.8198e-05 - val_accuracy: 0.0000e+00
# Epoch 4/50
#  - 1s - loss: 0.0034 - accuracy: 0.0000e+00 - val_loss: 0.0022 - val_accuracy: 0.0000e+00
# Epoch 5/50
#  - 1s - loss: 0.0035 - accuracy: 0.0000e+00 - val_loss: 3.3846e-05 - val_accuracy: 0.0000e+00
# Epoch 6/50
#  - 1s - loss: 0.0033 - accuracy: 0.0000e+00 - val_loss: 1.9049e-06 - val_accuracy: 0.0000e+00
# Epoch 7/50
#  - 1s - loss: 0.0030 - accuracy: 0.0000e+00 - val_loss: 1.2735e-04 - val_accuracy: 0.0000e+00
# Epoch 8/50
#  - 1s - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 9.7306e-04 - val_accuracy: 0.0000e+00
# Epoch 9/50
#  - 1s - loss: 0.0027 - accuracy: 0.0000e+00 - val_loss: 4.6199e-04 - val_accuracy: 0.0000e+00
# Epoch 10/50
#  - 1s - loss: 0.0026 - accuracy: 0.0000e+00 - val_loss: 2.4995e-04 - val_accuracy: 0.0000e+00
# Epoch 11/50
#  - 1s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 8.9304e-04 - val_accuracy: 0.0000e+00
# Epoch 12/50
#  - 1s - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 7.6585e-05 - val_accuracy: 0.0000e+00
# Epoch 13/50
#  - 1s - loss: 0.0023 - accuracy: 0.0000e+00 - val_loss: 5.1581e-04 - val_accuracy: 0.0000e+00
# Epoch 14/50
#  - 1s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 6.2231e-04 - val_accuracy: 0.0000e+00
# Epoch 15/50
#  - 1s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 2.0060e-04 - val_accuracy: 0.0000e+00
# Epoch 16/50
#  - 1s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 4.3423e-04 - val_accuracy: 0.0000e+00
# Epoch 17/50
#  - 1s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 7.9088e-05 - val_accuracy: 0.0000e+00
# Epoch 18/50
#  - 2s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 4.8027e-05 - val_accuracy: 0.0000e+00
# Epoch 19/50
#  - 1s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 9.1128e-04 - val_accuracy: 0.0000e+00
# Epoch 20/50
#  - 1s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 1.7491e-04 - val_accuracy: 0.0000e+00
# Epoch 21/50
#  - 1s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 8.5156e-04 - val_accuracy: 0.0000e+00
# Epoch 22/50
#  - 1s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 4.9962e-04 - val_accuracy: 0.0000e+00
# Epoch 23/50
#  - 1s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 7.5527e-05 - val_accuracy: 0.0000e+00
# Epoch 24/50
#  - 1s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 4.6402e-04 - val_accuracy: 0.0000e+00
# Epoch 25/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 1.6351e-04 - val_accuracy: 0.0000e+00
# Epoch 26/50
#  - 1s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 1.5566e-04 - val_accuracy: 0.0000e+00
# Epoch 27/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 3.3068e-05 - val_accuracy: 0.0000e+00
# Epoch 28/50
#  - 1s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 8.1514e-05 - val_accuracy: 0.0000e+00
# Epoch 29/50
#  - 1s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 5.6822e-05 - val_accuracy: 0.0000e+00
# Epoch 30/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 1.0190e-05 - val_accuracy: 0.0000e+00
# Epoch 31/50
#  - 1s - loss: 9.5648e-04 - accuracy: 0.0000e+00 - val_loss: 1.3226e-05 - val_accuracy: 0.0000e+00
# Epoch 32/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 6.1482e-05 - val_accuracy: 0.0000e+00
# Epoch 33/50
#  - 1s - loss: 8.3467e-04 - accuracy: 0.0000e+00 - val_loss: 7.9951e-05 - val_accuracy: 0.0000e+00
# Epoch 34/50
#  - 1s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 1.8233e-04 - val_accuracy: 0.0000e+00
# Epoch 35/50
#  - 1s - loss: 8.1194e-04 - accuracy: 0.0000e+00 - val_loss: 2.8759e-04 - val_accuracy: 0.0000e+00
# Epoch 36/50
#  - 1s - loss: 8.8793e-04 - accuracy: 0.0000e+00 - val_loss: 1.5170e-05 - val_accuracy: 0.0000e+00
# Epoch 37/50
#  - 1s - loss: 8.3582e-04 - accuracy: 0.0000e+00 - val_loss: 4.0338e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
#  - 1s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 2.4653e-04 - val_accuracy: 0.0000e+00
# Epoch 39/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 1.3938e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
#  - 1s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 1.0255e-04 - val_accuracy: 0.0000e+00
# Epoch 41/50
#  - 1s - loss: 9.1448e-04 - accuracy: 0.0000e+00 - val_loss: 5.5295e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
#  - 1s - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 2.6913e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
#  - 1s - loss: 8.1679e-04 - accuracy: 0.0000e+00 - val_loss: 2.1843e-05 - val_accuracy: 0.0000e+00
# Epoch 44/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 1.4064e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
#  - 1s - loss: 8.2752e-04 - accuracy: 0.0000e+00 - val_loss: 1.7219e-05 - val_accuracy: 0.0000e+00
# Epoch 46/50
#  - 1s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 3.7487e-05 - val_accuracy: 0.0000e+00
# Epoch 47/50
#  - 1s - loss: 8.5724e-04 - accuracy: 0.0000e+00 - val_loss: 3.0624e-04 - val_accuracy: 0.0000e+00
# Epoch 48/50
#  - 1s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 3.0835e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
#  - 1s - loss: 7.8672e-04 - accuracy: 0.0000e+00 - val_loss: 4.3859e-05 - val_accuracy: 0.0000e+00
# Epoch 50/50
#  - 1s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 4.6980e-04 - val_accuracy: 0.0000e+00
#
# Resumo do modelo
#
# Configuração utilizada: 4
# Time step (delta): 7
# Total de features: 8
# Tamanho do conjunto de treino: 6306
# Total de neurônios de entrada: 30
# Total de neurônios de saída: 1
# Total de épocas (epochs): 50
# Tamanho do arquivo de lote (batch size): 72
# Otimizador: adam
# Estimador de erro: mean_squared_error
#
#
# Model: "sequential_104"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_104 (LSTM)              (None, 30)                4680
# _________________________________________________________________
# dropout_104 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_104 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 4,711
# Trainable params: 4,711
# Non-trainable params: 0
# _________________________________________________________________
#
#
# => 4. Plotagem do histórico e da precisão...
# => 5. Realizando a predição...
#
# Train Score: 408827013222548.75
# Test Score: 510216910019.23
#
#
# AQUI----
# => 6. Plotagem da predição...
#
#
# Gráfico da predição total
# Gráfico da predição para 100 pontos
# Gráfico da predição dos 15 pontos finais
# ....................................................................................................
#
#
# * DELTA: 15
#
# => 1. Reestruturando o conjunto de dados para o formato adequado...
#
# Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: (7875, 128)
# Colunas removidas (7): ['var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)']
# Colunas utilizadas (121): ['var1(t-15)', 'var2(t-15)', 'var3(t-15)', 'var4(t-15)', 'var5(t-15)', 'var6(t-15)', 'var7(t-15)', 'var8(t-15)', 'var1(t-14)', 'var2(t-14)', 'var3(t-14)', 'var4(t-14)', 'var5(t-14)', 'var6(t-14)', 'var7(t-14)', 'var8(t-14)', 'var1(t-13)', 'var2(t-13)', 'var3(t-13)', 'var4(t-13)', 'var5(t-13)', 'var6(t-13)', 'var7(t-13)', 'var8(t-13)', 'var1(t-12)', 'var2(t-12)', 'var3(t-12)', 'var4(t-12)', 'var5(t-12)', 'var6(t-12)', 'var7(t-12)', 'var8(t-12)', 'var1(t-11)', 'var2(t-11)', 'var3(t-11)', 'var4(t-11)', 'var5(t-11)', 'var6(t-11)', 'var7(t-11)', 'var8(t-11)', 'var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var4(t-10)', 'var5(t-10)', 'var6(t-10)', 'var7(t-10)', 'var8(t-10)', 'var1(t-9)', 'var2(t-9)', 'var3(t-9)', 'var4(t-9)', 'var5(t-9)', 'var6(t-9)', 'var7(t-9)', 'var8(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var4(t-8)', 'var5(t-8)', 'var6(t-8)', 'var7(t-8)', 'var8(t-8)', 'var1(t-7)', 'var2(t-7)', 'var3(t-7)', 'var4(t-7)', 'var5(t-7)', 'var6(t-7)', 'var7(t-7)', 'var8(t-7)', 'var1(t-6)', 'var2(t-6)', 'var3(t-6)', 'var4(t-6)', 'var5(t-6)', 'var6(t-6)', 'var7(t-6)', 'var8(t-6)', 'var1(t-5)', 'var2(t-5)', 'var3(t-5)', 'var4(t-5)', 'var5(t-5)', 'var6(t-5)', 'var7(t-5)', 'var8(t-5)', 'var1(t-4)', 'var2(t-4)', 'var3(t-4)', 'var4(t-4)', 'var5(t-4)', 'var6(t-4)', 'var7(t-4)', 'var8(t-4)', 'var1(t-3)', 'var2(t-3)', 'var3(t-3)', 'var4(t-3)', 'var5(t-3)', 'var6(t-3)', 'var7(t-3)', 'var8(t-3)', 'var1(t-2)', 'var2(t-2)', 'var3(t-2)', 'var4(t-2)', 'var5(t-2)', 'var6(t-2)', 'var7(t-2)', 'var8(t-2)', 'var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)']
#
#
# => 2. Preparando os conjuntos de treinamento e de teste...
#
# Conjunto de treinamento gerado com 80.0% dos dados
# Dimensões do conjunto de treinamento: (6300, 120), 6300, (6300,)
# Dimensões dos conjuntos de treinamento e de teste: (6300, 15, 8), (6300,), (1575, 15, 8), (1575,)
#
#
# => 3. Realizando o treinamento da rede neural...
#
# Train on 6300 samples, validate on 1575 samples
# Epoch 1/50
#  - 3s - loss: 0.0071 - accuracy: 0.0000e+00 - val_loss: 4.6630e-04 - val_accuracy: 0.0000e+00
# Epoch 2/50
#  - 2s - loss: 0.0041 - accuracy: 0.0000e+00 - val_loss: 1.7171e-04 - val_accuracy: 0.0000e+00
# Epoch 3/50
#  - 2s - loss: 0.0034 - accuracy: 0.0000e+00 - val_loss: 9.3404e-05 - val_accuracy: 0.0000e+00
# Epoch 4/50
#  - 2s - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 9.7010e-04 - val_accuracy: 0.0000e+00
# Epoch 5/50
#  - 2s - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 7.7326e-07 - val_accuracy: 0.0000e+00
# Epoch 6/50
#  - 2s - loss: 0.0027 - accuracy: 0.0000e+00 - val_loss: 7.2134e-05 - val_accuracy: 0.0000e+00
# Epoch 7/50
#  - 2s - loss: 0.0027 - accuracy: 0.0000e+00 - val_loss: 1.4081e-04 - val_accuracy: 0.0000e+00
# Epoch 8/50
#  - 2s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 3.8319e-04 - val_accuracy: 0.0000e+00
# Epoch 9/50
#  - 2s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 4.2577e-04 - val_accuracy: 0.0000e+00
# Epoch 10/50
#  - 2s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 5.3184e-04 - val_accuracy: 0.0000e+00
# Epoch 11/50
#  - 2s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 12/50
#  - 2s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 0.0018 - val_accuracy: 0.0000e+00
# Epoch 13/50
#  - 2s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 1.2503e-04 - val_accuracy: 0.0000e+00
# Epoch 14/50
#  - 2s - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 8.0636e-04 - val_accuracy: 0.0000e+00
# Epoch 15/50
#  - 2s - loss: 0.0025 - accuracy: 0.0000e+00 - val_loss: 4.9703e-04 - val_accuracy: 0.0000e+00
# Epoch 16/50
#  - 2s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 4.7138e-05 - val_accuracy: 0.0000e+00
# Epoch 17/50
#  - 2s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 1.4935e-04 - val_accuracy: 0.0000e+00
# Epoch 18/50
#  - 2s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 8.0426e-05 - val_accuracy: 0.0000e+00
# Epoch 19/50
#  - 2s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 7.8544e-06 - val_accuracy: 0.0000e+00
# Epoch 20/50
#  - 2s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 6.6546e-05 - val_accuracy: 0.0000e+00
# Epoch 21/50
#  - 2s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 2.3531e-04 - val_accuracy: 0.0000e+00
# Epoch 22/50
#  - 2s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 5.1585e-05 - val_accuracy: 0.0000e+00
# Epoch 23/50
#  - 2s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 8.0569e-05 - val_accuracy: 0.0000e+00
# Epoch 24/50
#  - 2s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 2.2435e-05 - val_accuracy: 0.0000e+00
# Epoch 25/50
#  - 2s - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 1.5132e-04 - val_accuracy: 0.0000e+00
# Epoch 26/50
#  - 2s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 1.3531e-04 - val_accuracy: 0.0000e+00
# Epoch 27/50
#  - 2s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 1.8554e-04 - val_accuracy: 0.0000e+00
# Epoch 28/50
#  - 2s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 2.6953e-05 - val_accuracy: 0.0000e+00
# Epoch 29/50
#  - 2s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 6.8161e-05 - val_accuracy: 0.0000e+00
# Epoch 30/50
#  - 2s - loss: 8.3854e-04 - accuracy: 0.0000e+00 - val_loss: 3.0341e-04 - val_accuracy: 0.0000e+00
# Epoch 31/50
#  - 2s - loss: 9.6302e-04 - accuracy: 0.0000e+00 - val_loss: 1.4409e-05 - val_accuracy: 0.0000e+00
# Epoch 32/50
#  - 2s - loss: 9.2364e-04 - accuracy: 0.0000e+00 - val_loss: 6.8756e-05 - val_accuracy: 0.0000e+00
# Epoch 33/50
#  - 2s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 2.6854e-04 - val_accuracy: 0.0000e+00
# Epoch 34/50
#  - 2s - loss: 9.5954e-04 - accuracy: 0.0000e+00 - val_loss: 2.7308e-05 - val_accuracy: 0.0000e+00
# Epoch 35/50
#  - 2s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 5.7421e-05 - val_accuracy: 0.0000e+00
# Epoch 36/50
#  - 2s - loss: 9.0040e-04 - accuracy: 0.0000e+00 - val_loss: 3.3844e-05 - val_accuracy: 0.0000e+00
# Epoch 37/50
#  - 2s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 1.2765e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
#  - 2s - loss: 7.6061e-04 - accuracy: 0.0000e+00 - val_loss: 4.7607e-05 - val_accuracy: 0.0000e+00
# Epoch 39/50
#  - 2s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 1.5393e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
#  - 2s - loss: 8.1155e-04 - accuracy: 0.0000e+00 - val_loss: 3.2954e-05 - val_accuracy: 0.0000e+00
# Epoch 41/50
#  - 2s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 2.1539e-05 - val_accuracy: 0.0000e+00
# Epoch 42/50
#  - 2s - loss: 8.1068e-04 - accuracy: 0.0000e+00 - val_loss: 1.7719e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
#  - 2s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 1.9485e-04 - val_accuracy: 0.0000e+00
# Epoch 44/50
#  - 2s - loss: 8.4172e-04 - accuracy: 0.0000e+00 - val_loss: 2.2462e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
#  - 2s - loss: 0.0014 - accuracy: 0.0000e+00 - val_loss: 6.2648e-05 - val_accuracy: 0.0000e+00
# Epoch 46/50
#  - 2s - loss: 7.5308e-04 - accuracy: 0.0000e+00 - val_loss: 7.3451e-05 - val_accuracy: 0.0000e+00
# Epoch 47/50
#  - 2s - loss: 7.8584e-04 - accuracy: 0.0000e+00 - val_loss: 8.0903e-06 - val_accuracy: 0.0000e+00
# Epoch 48/50
#  - 2s - loss: 6.5981e-04 - accuracy: 0.0000e+00 - val_loss: 6.2862e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
#  - 2s - loss: 9.3878e-04 - accuracy: 0.0000e+00 - val_loss: 4.2523e-04 - val_accuracy: 0.0000e+00
# Epoch 50/50
#  - 2s - loss: 7.6247e-04 - accuracy: 0.0000e+00 - val_loss: 5.9450e-04 - val_accuracy: 0.0000e+00
#
# Resumo do modelo
#
# Configuração utilizada: 4
# Time step (delta): 15
# Total de features: 8
# Tamanho do conjunto de treino: 6300
# Total de neurônios de entrada: 30
# Total de neurônios de saída: 1
# Total de épocas (epochs): 50
# Tamanho do arquivo de lote (batch size): 72
# Otimizador: adam
# Estimador de erro: mean_squared_error
#
#
# Model: "sequential_105"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_105 (LSTM)              (None, 30)                4680
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_105 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 4,711
# Trainable params: 4,711
# Non-trainable params: 0
# _________________________________________________________________
#
#
# => 4. Plotagem do histórico e da precisão...
# => 5. Realizando a predição...
#
# Train Score: 465815778281045.00
# Test Score: 645642490223.57
#
#
# AQUI----
# => 6. Plotagem da predição...
#
#
# Gráfico da predição total
# Gráfico da predição para 100 pontos
# Gráfico da predição dos 15 pontos finais
# ....................................................................................................
#
#
# * DELTA: 30
#
# => 1. Reestruturando o conjunto de dados para o formato adequado...
#
# Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: (7860, 248)
# Colunas removidas (7): ['var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)']
# Colunas utilizadas (241): ['var1(t-30)', 'var2(t-30)', 'var3(t-30)', 'var4(t-30)', 'var5(t-30)', 'var6(t-30)', 'var7(t-30)', 'var8(t-30)', 'var1(t-29)', 'var2(t-29)', 'var3(t-29)', 'var4(t-29)', 'var5(t-29)', 'var6(t-29)', 'var7(t-29)', 'var8(t-29)', 'var1(t-28)', 'var2(t-28)', 'var3(t-28)', 'var4(t-28)', 'var5(t-28)', 'var6(t-28)', 'var7(t-28)', 'var8(t-28)', 'var1(t-27)', 'var2(t-27)', 'var3(t-27)', 'var4(t-27)', 'var5(t-27)', 'var6(t-27)', 'var7(t-27)', 'var8(t-27)', 'var1(t-26)', 'var2(t-26)', 'var3(t-26)', 'var4(t-26)', 'var5(t-26)', 'var6(t-26)', 'var7(t-26)', 'var8(t-26)', 'var1(t-25)', 'var2(t-25)', 'var3(t-25)', 'var4(t-25)', 'var5(t-25)', 'var6(t-25)', 'var7(t-25)', 'var8(t-25)', 'var1(t-24)', 'var2(t-24)', 'var3(t-24)', 'var4(t-24)', 'var5(t-24)', 'var6(t-24)', 'var7(t-24)', 'var8(t-24)', 'var1(t-23)', 'var2(t-23)', 'var3(t-23)', 'var4(t-23)', 'var5(t-23)', 'var6(t-23)', 'var7(t-23)', 'var8(t-23)', 'var1(t-22)', 'var2(t-22)', 'var3(t-22)', 'var4(t-22)', 'var5(t-22)', 'var6(t-22)', 'var7(t-22)', 'var8(t-22)', 'var1(t-21)', 'var2(t-21)', 'var3(t-21)', 'var4(t-21)', 'var5(t-21)', 'var6(t-21)', 'var7(t-21)', 'var8(t-21)', 'var1(t-20)', 'var2(t-20)', 'var3(t-20)', 'var4(t-20)', 'var5(t-20)', 'var6(t-20)', 'var7(t-20)', 'var8(t-20)', 'var1(t-19)', 'var2(t-19)', 'var3(t-19)', 'var4(t-19)', 'var5(t-19)', 'var6(t-19)', 'var7(t-19)', 'var8(t-19)', 'var1(t-18)', 'var2(t-18)', 'var3(t-18)', 'var4(t-18)', 'var5(t-18)', 'var6(t-18)', 'var7(t-18)', 'var8(t-18)', 'var1(t-17)', 'var2(t-17)', 'var3(t-17)', 'var4(t-17)', 'var5(t-17)', 'var6(t-17)', 'var7(t-17)', 'var8(t-17)', 'var1(t-16)', 'var2(t-16)', 'var3(t-16)', 'var4(t-16)', 'var5(t-16)', 'var6(t-16)', 'var7(t-16)', 'var8(t-16)', 'var1(t-15)', 'var2(t-15)', 'var3(t-15)', 'var4(t-15)', 'var5(t-15)', 'var6(t-15)', 'var7(t-15)', 'var8(t-15)', 'var1(t-14)', 'var2(t-14)', 'var3(t-14)', 'var4(t-14)', 'var5(t-14)', 'var6(t-14)', 'var7(t-14)', 'var8(t-14)', 'var1(t-13)', 'var2(t-13)', 'var3(t-13)', 'var4(t-13)', 'var5(t-13)', 'var6(t-13)', 'var7(t-13)', 'var8(t-13)', 'var1(t-12)', 'var2(t-12)', 'var3(t-12)', 'var4(t-12)', 'var5(t-12)', 'var6(t-12)', 'var7(t-12)', 'var8(t-12)', 'var1(t-11)', 'var2(t-11)', 'var3(t-11)', 'var4(t-11)', 'var5(t-11)', 'var6(t-11)', 'var7(t-11)', 'var8(t-11)', 'var1(t-10)', 'var2(t-10)', 'var3(t-10)', 'var4(t-10)', 'var5(t-10)', 'var6(t-10)', 'var7(t-10)', 'var8(t-10)', 'var1(t-9)', 'var2(t-9)', 'var3(t-9)', 'var4(t-9)', 'var5(t-9)', 'var6(t-9)', 'var7(t-9)', 'var8(t-9)', 'var1(t-8)', 'var2(t-8)', 'var3(t-8)', 'var4(t-8)', 'var5(t-8)', 'var6(t-8)', 'var7(t-8)', 'var8(t-8)', 'var1(t-7)', 'var2(t-7)', 'var3(t-7)', 'var4(t-7)', 'var5(t-7)', 'var6(t-7)', 'var7(t-7)', 'var8(t-7)', 'var1(t-6)', 'var2(t-6)', 'var3(t-6)', 'var4(t-6)', 'var5(t-6)', 'var6(t-6)', 'var7(t-6)', 'var8(t-6)', 'var1(t-5)', 'var2(t-5)', 'var3(t-5)', 'var4(t-5)', 'var5(t-5)', 'var6(t-5)', 'var7(t-5)', 'var8(t-5)', 'var1(t-4)', 'var2(t-4)', 'var3(t-4)', 'var4(t-4)', 'var5(t-4)', 'var6(t-4)', 'var7(t-4)', 'var8(t-4)', 'var1(t-3)', 'var2(t-3)', 'var3(t-3)', 'var4(t-3)', 'var5(t-3)', 'var6(t-3)', 'var7(t-3)', 'var8(t-3)', 'var1(t-2)', 'var2(t-2)', 'var3(t-2)', 'var4(t-2)', 'var5(t-2)', 'var6(t-2)', 'var7(t-2)', 'var8(t-2)', 'var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)', 'var1(t)']
#
#
# => 2. Preparando os conjuntos de treinamento e de teste...
#
# Conjunto de treinamento gerado com 80.0% dos dados
# Dimensões do conjunto de treinamento: (6288, 240), 6288, (6288,)
# Dimensões dos conjuntos de treinamento e de teste: (6288, 30, 8), (6288,), (1572, 30, 8), (1572,)
#
#
# => 3. Realizando o treinamento da rede neural...
#
# Train on 6288 samples, validate on 1572 samples
# Epoch 1/50
#  - 4s - loss: 0.0181 - accuracy: 0.0000e+00 - val_loss: 7.7870e-04 - val_accuracy: 0.0000e+00
# Epoch 2/50
#  - 4s - loss: 0.0058 - accuracy: 0.0000e+00 - val_loss: 8.4930e-04 - val_accuracy: 0.0000e+00
# Epoch 3/50
#  - 4s - loss: 0.0044 - accuracy: 0.0000e+00 - val_loss: 1.2257e-04 - val_accuracy: 0.0000e+00
# Epoch 4/50
#  - 4s - loss: 0.0039 - accuracy: 0.0000e+00 - val_loss: 1.8386e-05 - val_accuracy: 0.0000e+00
# Epoch 5/50
#  - 4s - loss: 0.0034 - accuracy: 0.0000e+00 - val_loss: 4.9294e-06 - val_accuracy: 0.0000e+00
# Epoch 6/50
#  - 5s - loss: 0.0037 - accuracy: 0.0000e+00 - val_loss: 1.0938e-05 - val_accuracy: 0.0000e+00
# Epoch 7/50
#  - 6s - loss: 0.0036 - accuracy: 0.0000e+00 - val_loss: 3.3188e-04 - val_accuracy: 0.0000e+00
# Epoch 8/50
#  - 5s - loss: 0.0035 - accuracy: 0.0000e+00 - val_loss: 7.7864e-04 - val_accuracy: 0.0000e+00
# Epoch 9/50
#  - 3s - loss: 0.0033 - accuracy: 0.0000e+00 - val_loss: 3.4404e-04 - val_accuracy: 0.0000e+00
# Epoch 10/50
#  - 3s - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 3.4018e-04 - val_accuracy: 0.0000e+00
# Epoch 11/50
#  - 3s - loss: 0.0029 - accuracy: 0.0000e+00 - val_loss: 9.8094e-04 - val_accuracy: 0.0000e+00
# Epoch 12/50
#  - 3s - loss: 0.0026 - accuracy: 0.0000e+00 - val_loss: 4.7877e-04 - val_accuracy: 0.0000e+00
# Epoch 13/50
#  - 3s - loss: 0.0026 - accuracy: 0.0000e+00 - val_loss: 1.9588e-04 - val_accuracy: 0.0000e+00
# Epoch 14/50
#  - 3s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 5.3686e-06 - val_accuracy: 0.0000e+00
# Epoch 15/50
#  - 3s - loss: 0.0023 - accuracy: 0.0000e+00 - val_loss: 3.1073e-05 - val_accuracy: 0.0000e+00
# Epoch 16/50
#  - 3s - loss: 0.0023 - accuracy: 0.0000e+00 - val_loss: 1.0617e-04 - val_accuracy: 0.0000e+00
# Epoch 17/50
#  - 3s - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 3.6123e-04 - val_accuracy: 0.0000e+00
# Epoch 18/50
#  - 3s - loss: 0.0020 - accuracy: 0.0000e+00 - val_loss: 4.3785e-04 - val_accuracy: 0.0000e+00
# Epoch 19/50
#  - 3s - loss: 0.0020 - accuracy: 0.0000e+00 - val_loss: 1.4016e-05 - val_accuracy: 0.0000e+00
# Epoch 20/50
#  - 4s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 1.1952e-05 - val_accuracy: 0.0000e+00
# Epoch 21/50
#  - 4s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 1.2190e-05 - val_accuracy: 0.0000e+00
# Epoch 22/50
#  - 4s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 9.4167e-05 - val_accuracy: 0.0000e+00
# Epoch 23/50
#  - 3s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 8.6731e-04 - val_accuracy: 0.0000e+00
# Epoch 24/50
#  - 3s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 1.7308e-04 - val_accuracy: 0.0000e+00
# Epoch 25/50
#  - 3s - loss: 0.0018 - accuracy: 0.0000e+00 - val_loss: 4.9759e-04 - val_accuracy: 0.0000e+00
# Epoch 26/50
#  - 3s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 1.6311e-04 - val_accuracy: 0.0000e+00
# Epoch 27/50
#  - 3s - loss: 0.0028 - accuracy: 0.0000e+00 - val_loss: 1.6397e-04 - val_accuracy: 0.0000e+00
# Epoch 28/50
#  - 4s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 2.8307e-05 - val_accuracy: 0.0000e+00
# Epoch 29/50
#  - 5s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 9.0625e-05 - val_accuracy: 0.0000e+00
# Epoch 30/50
#  - 4s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 4.8137e-04 - val_accuracy: 0.0000e+00
# Epoch 31/50
#  - 4s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 2.9345e-04 - val_accuracy: 0.0000e+00
# Epoch 32/50
#  - 4s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 1.8927e-04 - val_accuracy: 0.0000e+00
# Epoch 33/50
#  - 4s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 6.4888e-04 - val_accuracy: 0.0000e+00
# Epoch 34/50
#  - 3s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 2.4323e-04 - val_accuracy: 0.0000e+00
# Epoch 35/50
#  - 4s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 1.0074e-04 - val_accuracy: 0.0000e+00
# Epoch 36/50
#  - 4s - loss: 9.8598e-04 - accuracy: 0.0000e+00 - val_loss: 2.9926e-04 - val_accuracy: 0.0000e+00
# Epoch 37/50
#  - 4s - loss: 8.9669e-04 - accuracy: 0.0000e+00 - val_loss: 5.9324e-04 - val_accuracy: 0.0000e+00
# Epoch 38/50
#  - 3s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 7.2697e-05 - val_accuracy: 0.0000e+00
# Epoch 39/50
#  - 3s - loss: 9.9963e-04 - accuracy: 0.0000e+00 - val_loss: 2.9640e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
#  - 3s - loss: 8.9380e-04 - accuracy: 0.0000e+00 - val_loss: 9.4973e-05 - val_accuracy: 0.0000e+00
# Epoch 41/50
#  - 3s - loss: 8.3693e-04 - accuracy: 0.0000e+00 - val_loss: 9.7754e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
#  - 3s - loss: 8.4271e-04 - accuracy: 0.0000e+00 - val_loss: 5.1479e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
#  - 3s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 7.6519e-04 - val_accuracy: 0.0000e+00
# Epoch 44/50
#  - 3s - loss: 0.0010 - accuracy: 0.0000e+00 - val_loss: 6.1467e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
#  - 3s - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 6.1398e-04 - val_accuracy: 0.0000e+00
# Epoch 46/50
#  - 3s - loss: 7.2300e-04 - accuracy: 0.0000e+00 - val_loss: 1.6552e-04 - val_accuracy: 0.0000e+00
# Epoch 47/50
#  - 3s - loss: 8.3080e-04 - accuracy: 0.0000e+00 - val_loss: 2.8216e-05 - val_accuracy: 0.0000e+00
# Epoch 48/50
#  - 3s - loss: 8.4658e-04 - accuracy: 0.0000e+00 - val_loss: 2.0317e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
#  - 3s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 5.9047e-05 - val_accuracy: 0.0000e+00
# Epoch 50/50
#  - 3s - loss: 7.0507e-04 - accuracy: 0.0000e+00 - val_loss: 1.6915e-04 - val_accuracy: 0.0000e+00
#
# Resumo do modelo
#
# Configuração utilizada: 4
# Time step (delta): 30
# Total de features: 8
# Tamanho do conjunto de treino: 6288
# Total de neurônios de entrada: 30
# Total de neurônios de saída: 1
# Total de épocas (epochs): 50
# Tamanho do arquivo de lote (batch size): 72
# Otimizador: adam
# Estimador de erro: mean_squared_error
#
#
# Model: "sequential_106"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_106 (LSTM)              (None, 30)                4680
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_106 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 4,711
# Trainable params: 4,711
# Non-trainable params: 0
# _________________________________________________________________
#
#
# => 4. Plotagem do histórico e da precisão...
# => 5. Realizando a predição...
#
# Train Score: 413596868107504.44
# Test Score: 183699407641.44
#
#
# AQUI----
# => 6. Plotagem da predição...
#
#
# Gráfico da predição total
# Gráfico da predição para 100 pontos
# Gráfico da predição dos 15 pontos finais
# ....................................................................................................
#
#
# * DELTA: 60
#
# => 1. Reestruturando o conjunto de dados para o formato adequado...
#
# Dimensões do arquivo reestruturado para o formato de aprendizado supervisionado: (7830, 488)
# Colunas removidas (7): ['var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)', 'var7(t)', 'var8(t)']
# Colunas utilizadas (481): ['var1(t-60)', 'var2(t-60)', 'var3(t-60)', 'var4(t-60)', 'var5(t-60)', 'var6(t-60)', 'var7(t-60)', 'var8(t-60)', 'var1(t-59)', 'var2(t-59)', 'var3(t-59)', 'var4(t-59)', 'var5(t-59)', 'var6(t-59)', 'var7(t-59)', 'var8(t-59)', 'var1(t-58)', 'var2(t-58)', 'var3(t-58)', 'var4(t-58)', 'var5(t-58)', 'var6(t-58)', 'var7(t-58)', 'var8(t-58)', 'var1(t-57)', 'var2(t-57)', 'var3(t-57)', 'var4(t-57)', 'var5(t-57)', 'var6(t-57)', 'var7(t-57)', 'var8(t-57)', 'var1(t-56)', 'var2(t-56)', 'var3(t-56)', 'var4(t-56)', 'var5(t-56)', 'var6(t-56)', 'var7(t-56)', 'var8(t-56)', 'var1(t-55)', 'var2(t-55)', 'var3(t-55)', 'var4(t-55)', 'var5(t-55)', 'var6(t-55)', 'var7(t-55)', 'var8(t-55)', 'var1(t-54)', 'var2(t-54)', 'var3(t-54)', 'var4(t-54)', 'var5(t-54)', 'var6(t-54)', 'var7(t-54)', 'var8(t-54)', 'var1(t-53)', 'var2(t-53)', 'var3(t-53)', 'var4(t-53)', 'var5(t-53)', 'var6(t-53)', 'var7(t-53)', 'var8(t-53)', 'var1(t-52)', 'var2(t-52)', 'var3(t-52)', 'var4(t-52)', 'var5(t-52)', 'var6(t-52)', 'var7(t-52)', 'var8(t-52)', 'var1(t-51)', 'var2(t-51)', 'var3(t-51)', 'var4(t-51)', 'var5(t-51)', 'var6(t-51)', 'var7(t-51)', 'var8(t-51)', 'var1(t-50)', 'var2(t-50)', 'var3(t-50)', 'var4(t-50)', 'var5(t-50)', 'var6(t-50)', 'var7(t-50)', 'var8(t-50)', 'var1(t-49)', 'var2(t-49)', 'var3(t-49)', 'var4(t-49)', 'var5(t-49)', 'var6(t-49)', 'var7(t-49)', 'var8(t-49)', 'var1(t-48)', 'var2(t-48)', 'var3(t-48)', 'var4(t-48)', 'var5(t-48)', 'var6(t-48)', 'var7(t-48)', 'var8(t-48)', 'var1(t-47)', 'var2(t-47)', 'var3(t-47)', 'var4(t-47)', 'var5(t-47)', 'var6(t-47)', 'var7(t-47)', 'var8(t-47)', 'var1(t-46)', 'var2(t-46)', 'var3(t-46)', 'var4(t-46)', 'var5(t-46)', 'var6(t-46)', 'var7(t-46)', 'var8(t-46)', 'var1(t-45)', 'var2(t-45)', 'var3(t-45)', 'var4(t-45)', 'var5(t-45)', 'var6(t-45)', 'var7(t-45)', 'var8(t-45)', 'var1(t-44)', 'var2(t-44)', 'var3(t-44)', 'var4(t-44)', 'var5(t-44)', 'var6(t-44)', 'var7(t-44)', 'var8(t-44)', 'var1(t-43)', 'var2(t-43)', 'var3(t-43)', 'var4(t-43)', 'var5(t-43)', 'var6(t-43)', 'var7(t-43)', 'var8(t-43)', 'var1(t-42)', 'var2(t-42)', 'var3(t-42)', 'var4(t-42)', 'var5(t-42)', 'var6(t-42)', 'var7(t-42)', 'var8(t-42)', 'var1(t-41)', 'var2(t-41)', 'var3(t-41)', 'var4(t-41)', 'var5(t-41)', 'var6(t-41)', 'var7(t-41)', 'var8(t-41)', 'var1(t-40)', 'var2(t-40)', 'var3(t-40)', 'var4(t-40)', 'var5(t-40)', 'var6(t-40)', 'var7(t-40)', 'var8(t-40)', 'var1(t-39)', 'var2(t-39)', 'var3(t-39)', 'var4(t-39)', 'var5(t-39)', 'var6(t-39)', 'var7(t-39)', 'var8(t-39)', 'var1(t-38)', 'var2(t-38)', 'var3(t-38)', 'var4(t-38)', 'var5(t-38)', 'var6(t-38)', 'var7(t-38)', 'var8(t-38)', 'var1(t-37)', 'var2(t-37)', 'var3(t-37)', 'var4(t-37)', 'var5(t-37)', 'var6(t-37)', 'var7(t-37)', 'var8(t-37)', 'var1(t-36)', 'var2(t-36)', 'var3(t-36)', 'var4(t-36)', 'var5(t-36)', 'var6(t-36)', 'var7(t-36)', 'var8(t-36)', 'var1(t-35)', 'var2(t-35)', 'var3(t-35)', 'var4(t-35)', 'var5(t-35)', 'var6(t-35)', 'var7(t-35)', 'var8(t-35)', 'var1(t-34)', 'var2(t-34)', 'var3(t-34)', 'var4(t-34)', 'var5(t-34)', 'var6(t-34)', 'var7(t-34)', 'var8(t-34)', 'var1(t-33)', 'var2(t-33)', 'var3(t-33)', 'var4(t-33)', 'var5(t-33)', 'var6(t-33)', 'var7(t-33)', 'var8(t-33)', 'var1(t-32)', 'var2(t-32)', 'var3(t-32)', 'var4(t-32)', 'var5(t-32)', 'var6(t-32)', 'var7(t-32)', 'var8(t-32)', 'var1(t-31)', 'var2(t-31)', 'var3(t-31)', 'var4(t-31)', 'var5(t-31)', 'var6(t-31)', 'var7(t-31)', 'var8(t-31)', 'var1(t-30)', 'var2(t-30)', 'var3(t-30)', 'var4(t-30)', 'var5(t-30)', 'var6(t-30)', 'var7(t-30)', 'var8(t-30)', 'var1(t-29)', 'var2(t-29)', 'var3(t-29)', 'var4(t-29)', 'var5(t-29)', 'var6(t-29)', 'var7(t-29)', 'var8(t-29)', 'var1(t-28)', 'var2(t-28)', 'var3(t-28)', 'var4(t-28)', 'var5(t-28)', 'var6(t-28)', 'var7(t-28)', 'var8(t-28)', 'var1(t-27)', 'var2(t-27)', 'var3(t-27)', 'var4(t-27)', 'var5(t-27)', 'var6(t-27)', 'var7(t-27)', 'var8(t-27)', 'var1(t-26)', 'var2(t-26)', 'var3(t-26)', 'var4(t-26)', 'var5(t-26)', 'var6(t-26)', 'var7(t-26)', 'var8(t-26)', 'var1(t-25)', 'var2(t-25)', 'var3(t-25)', 'var4(t-25) ...
#
#
# => 2. Preparando os conjuntos de treinamento e de teste...
#
# Conjunto de treinamento gerado com 80.0% dos dados
# Dimensões do conjunto de treinamento: (6264, 480), 6264, (6264,)
# Dimensões dos conjuntos de treinamento e de teste: (6264, 60, 8), (6264,), (1566, 60, 8), (1566,)
#
#
# => 3. Realizando o treinamento da rede neural...
#
# Train on 6264 samples, validate on 1566 samples
# Epoch 1/50
#  - 7s - loss: 0.0080 - accuracy: 0.0000e+00 - val_loss: 0.0149 - val_accuracy: 0.0000e+00
# Epoch 2/50
#  - 8s - loss: 0.0049 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 3/50
#  - 7s - loss: 0.0037 - accuracy: 0.0000e+00 - val_loss: 0.0040 - val_accuracy: 0.0000e+00
# Epoch 4/50
#  - 7s - loss: 0.0033 - accuracy: 0.0000e+00 - val_loss: 0.0045 - val_accuracy: 0.0000e+00
# Epoch 5/50
#  - 7s - loss: 0.0031 - accuracy: 0.0000e+00 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 6/50
#  - 7s - loss: 0.0030 - accuracy: 0.0000e+00 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 7/50
#  - 7s - loss: 0.0026 - accuracy: 0.0000e+00 - val_loss: 0.0041 - val_accuracy: 0.0000e+00
# Epoch 8/50
#  - 7s - loss: 0.0027 - accuracy: 0.0000e+00 - val_loss: 0.0056 - val_accuracy: 0.0000e+00
# Epoch 9/50
#  - 7s - loss: 0.0026 - accuracy: 0.0000e+00 - val_loss: 0.0069 - val_accuracy: 0.0000e+00
# Epoch 10/50
#  - 7s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 0.0026 - val_accuracy: 0.0000e+00
# Epoch 11/50
#  - 10s - loss: 0.0023 - accuracy: 0.0000e+00 - val_loss: 0.0032 - val_accuracy: 0.0000e+00
# Epoch 12/50
#  - 10s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 0.0021 - val_accuracy: 0.0000e+00
# Epoch 13/50
#  - 10s - loss: 0.0021 - accuracy: 0.0000e+00 - val_loss: 0.0036 - val_accuracy: 0.0000e+00
# Epoch 14/50
#  - 7s - loss: 0.0020 - accuracy: 0.0000e+00 - val_loss: 0.0038 - val_accuracy: 0.0000e+00
# Epoch 15/50
#  - 8s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 0.0030 - val_accuracy: 0.0000e+00
# Epoch 16/50
#  - 8s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 17/50
#  - 7s - loss: 0.0017 - accuracy: 0.0000e+00 - val_loss: 0.0016 - val_accuracy: 0.0000e+00
# Epoch 18/50
#  - 8s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 19/50
#  - 8s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0015 - val_accuracy: 0.0000e+00
# Epoch 20/50
#  - 8s - loss: 0.0015 - accuracy: 0.0000e+00 - val_loss: 0.0040 - val_accuracy: 0.0000e+00
# Epoch 21/50
#  - 8s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 22/50
#  - 7s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 23/50
#  - 7s - loss: 0.0012 - accuracy: 0.0000e+00 - val_loss: 0.0031 - val_accuracy: 0.0000e+00
# Epoch 24/50
#  - 6s - loss: 0.0016 - accuracy: 0.0000e+00 - val_loss: 0.0027 - val_accuracy: 0.0000e+00
# Epoch 25/50
#  - 6s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0035 - val_accuracy: 0.0000e+00
# Epoch 26/50
#  - 8s - loss: 0.0011 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 27/50
#  - 7s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0012 - val_accuracy: 0.0000e+00
# Epoch 28/50
#  - 7s - loss: 0.0013 - accuracy: 0.0000e+00 - val_loss: 0.0019 - val_accuracy: 0.0000e+00
# Epoch 29/50
#  - 7s - loss: 0.0022 - accuracy: 0.0000e+00 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 30/50
#  - 7s - loss: 9.3087e-04 - accuracy: 0.0000e+00 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 31/50
#  - 7s - loss: 9.8138e-04 - accuracy: 0.0000e+00 - val_loss: 9.7089e-04 - val_accuracy: 0.0000e+00
# Epoch 32/50
#  - 7s - loss: 9.2573e-04 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 33/50
#  - 7s - loss: 8.6401e-04 - accuracy: 0.0000e+00 - val_loss: 0.0011 - val_accuracy: 0.0000e+00
# Epoch 34/50
#  - 7s - loss: 8.1656e-04 - accuracy: 0.0000e+00 - val_loss: 0.0029 - val_accuracy: 0.0000e+00
# Epoch 35/50
#  - 7s - loss: 7.3109e-04 - accuracy: 0.0000e+00 - val_loss: 0.0014 - val_accuracy: 0.0000e+00
# Epoch 36/50
#  - 7s - loss: 8.8027e-04 - accuracy: 0.0000e+00 - val_loss: 7.1380e-04 - val_accuracy: 0.0000e+00
# Epoch 37/50
#  - 7s - loss: 9.8582e-04 - accuracy: 0.0000e+00 - val_loss: 0.0013 - val_accuracy: 0.0000e+00
# Epoch 38/50
#  - 7s - loss: 0.0019 - accuracy: 0.0000e+00 - val_loss: 9.2562e-04 - val_accuracy: 0.0000e+00
# Epoch 39/50
#  - 7s - loss: 7.1769e-04 - accuracy: 0.0000e+00 - val_loss: 6.5298e-04 - val_accuracy: 0.0000e+00
# Epoch 40/50
#  - 7s - loss: 7.7989e-04 - accuracy: 0.0000e+00 - val_loss: 7.2239e-04 - val_accuracy: 0.0000e+00
# Epoch 41/50
#  - 7s - loss: 6.5680e-04 - accuracy: 0.0000e+00 - val_loss: 6.8897e-04 - val_accuracy: 0.0000e+00
# Epoch 42/50
#  - 7s - loss: 6.9341e-04 - accuracy: 0.0000e+00 - val_loss: 3.9035e-04 - val_accuracy: 0.0000e+00
# Epoch 43/50
#  - 7s - loss: 6.1402e-04 - accuracy: 0.0000e+00 - val_loss: 4.3818e-04 - val_accuracy: 0.0000e+00
# Epoch 44/50
#  - 7s - loss: 9.8532e-04 - accuracy: 0.0000e+00 - val_loss: 5.2275e-04 - val_accuracy: 0.0000e+00
# Epoch 45/50
#  - 7s - loss: 8.2536e-04 - accuracy: 0.0000e+00 - val_loss: 5.5668e-04 - val_accuracy: 0.0000e+00
# Epoch 46/50
#  - 7s - loss: 0.0024 - accuracy: 0.0000e+00 - val_loss: 2.2528e-04 - val_accuracy: 0.0000e+00
# Epoch 47/50
#  - 7s - loss: 6.1501e-04 - accuracy: 0.0000e+00 - val_loss: 3.5737e-04 - val_accuracy: 0.0000e+00
# Epoch 48/50
#  - 8s - loss: 7.5819e-04 - accuracy: 0.0000e+00 - val_loss: 4.1673e-04 - val_accuracy: 0.0000e+00
# Epoch 49/50
#  - 7s - loss: 5.9542e-04 - accuracy: 0.0000e+00 - val_loss: 0.0010 - val_accuracy: 0.0000e+00
# Epoch 50/50
#  - 7s - loss: 9.5584e-04 - accuracy: 0.0000e+00 - val_loss: 5.1435e-04 - val_accuracy: 0.0000e+00
#
# Resumo do modelo
#
# Configuração utilizada: 4
# Time step (delta): 60
# Total de features: 8
# Tamanho do conjunto de treino: 6264
# Total de neurônios de entrada: 30
# Total de neurônios de saída: 1
# Total de épocas (epochs): 50
# Tamanho do arquivo de lote (batch size): 72
# Otimizador: adam
# Estimador de erro: mean_squared_error
#
#
# Model: "sequential_107"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_107 (LSTM)              (None, 30)                4680
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 30)                0
# _________________________________________________________________
# dense_107 (Dense)            (None, 1)                 31
# =================================================================
# Total params: 4,711
# Trainable params: 4,711
# Non-trainable params: 0
# _________________________________________________________________
#
#
# => 4. Plotagem do histórico e da precisão...
# => 5. Realizando a predição...
#
# Train Score: 429977259179716.00
# Test Score: 558603500995.17
#
#
# AQUI----
# => 6. Plotagem da predição...
#
#
# Gráfico da predição total
# Gráfico da predição para 100 pontos
# Gráfico da predição dos 15 pontos finais
# ----------------------------------------------------------------------------------------------------
#
#
# => Salvando as predições... -> predicoes_4.csv
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-310-eff352b6e6f2> in <module>()
#     577 for i, valor in enumerate(inv_yhat_list):
#     578     #s = ','.join(map(str, valor[6]))
# --> 579     s = ','.join(map(str, valor[4]))
#     580     linha += f"{i+1}, {valor[0]}, {s}\n"
#     581
#
# TypeError: 'float' object is not iterable

# %%
# Ordena
#inv_y.sort()
#inv_yhat.sort()

N = len(inv_yhat)
start = 0 #2200
aa=[x for x in range(N)]
#plt.figure(figsize=(8,4))
plt.plot(aa[start:N], inv_y[start:N], marker='.', label="Atual")
plt.plot(aa[start:N], inv_yhat[start:N], 'r', label="Predição")
plt.tight_layout()
#sns.despine(top=True)
plt.subplots_adjust(left=0.07)
plt.ylabel('Casos Confirmados', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show();

# %%
# Define alguns pontos
N = 100
pred = 15
N = N-pred

observacao = inv_y[0:N,]
modelo = inv_yhat[N:N + pred,]

x1 = np.arange(len(observacao))
x2 = np.arange(len(observacao), len(observacao) + pred)

print(f"Gráfico da predição dos {pred} pontos finais\n\n")

# Plotagem da predição dos pontos finais
plt.figure(figsize=(8, 6))
plt.plot(x1, inv_y[:N], marker='o', color='k', alpha=0.4, label="Observacao");
plt.plot(inv_yhat[0:N + pred,], linewidth=1, color='r', label='Modelo Total');
plt.plot(x2, modelo, color='b', linewidth=1, label='Modelo Final');
plt.title(f"Predição de Casos COVID-19, Delta: {delta}", fontsize=18, y=1.01);
plt.ylabel('Casos Confirmados', fontsize=18);
plt.xlabel('Time Step', fontsize=18);
plt.legend(bbox_to_anchor=(1.31,1.02), fontsize=13);
plt.show();
# Out:
# Gráfico da predição dos 15 pontos finais

# %%
r = inv_y - inv_yhat

plt.plot(r);

# %%
df = pd.read_csv('data/covid19-atributo-valor.csv', header=0, index_col=0)

cols = df.columns

for c in cols:
    print(f"'{c}',")
# Out:
# 'Código do País',
# 'Latitude',
# 'Longitude',
# 'PIB 2019',
# 'População',
# 'População Urbana',
# 'Área (Km/2)',
# 'Densidade (Km/2)',
# 'Taxa de Fertilidade',
# 'Média de Idade',
# 'Taxa de Fumantes',
# 'Taxa de Mortalidade por Doenças Pulmonares',
# 'Total de Leitos Hospitalares',
# 'Temperatura Média (Janeiro - Março)',
# 'Taxa de Umidade (Janeiro - Março)',
# 'Casos Confirmados',

# %%
df['Casos Confirmados'].cumsum()
# Out:
# Data
# 2020-01-22           0
# 2020-01-22           0
# 2020-01-22           0
# 2020-01-22           0
# 2020-01-22           0
#                 ...
# 2020-04-15    32955408
# 2020-04-15    32955414
# 2020-04-15    32955415
# 2020-04-15    32955463
# 2020-04-15    32955486
# Name: Casos Confirmados, Length: 15555, dtype: int64

# %%
df['Casos Confirmados'].cumsum().plot()

# %%
3.0 * 1e7
# Out:
# 30000000.0

# %%
a = inv_yhat_list[0][6]

# %%
e = df['Casos Confirmados'].values.cumsum()

N = 500

for i in range(3):
    d = inv_yhat_list[i][6]
    l = inv_yhat_list[i][0]
    d.sort()
    plt.plot(d[0:N], marker='.', label=f'Delta: {l}');
    
plt.plot(e[0:N], label='Casos Confirmados');
plt.title('Predições x Casos Confirmados');
plt.xlabel('Tempo');
plt.ylabel('Total de Casos');
plt.xticks(fontsize=16);
plt.yticks(fontsize=16);
plt.legend(bbox_to_anchor=(1.33,1.017), fontsize=13);

# %%
casos = dataframe.values
    
plt.plot(casos, color='lightgrey', marker='o', markersize=5, alpha=0.85, label='Casos Confirmados');
plt.plot(trainPredictPlot, color='b',label='Treino');
plt.plot(testPredictPlot, color='r', label='Predição');
plt.title('Predições x Casos Confirmados', fontsize=22);
plt.xlabel('Tempo', fontsize=18);
plt.ylabel('Total de Casos', fontsize=18);
plt.xticks(fontsize=16);
plt.yticks(fontsize=16);
#plt.legend(bbox_to_anchor=(1.33,1.017), fontsize=13);
plt.legend(loc='upper left', fontsize=13);
