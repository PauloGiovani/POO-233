# %% [markdown]
# # Aprendizado de Máquina Aplicada à Análise de Dados do COVID-19
#
# - Aluno: Paulo Giovani de Faria Zeferino
#
# Este documento contém os passos utilizados para o desenvolvimento do artigo **Aprendizado de Máquina Aplicada à Análise de Dados do COVID-19**, solicitado pelo professor Filipe Verri para a disciplina PO-233/2018 Aprendizado de Máquina, oferecida pelo curso de pós-graduação do ITA.
#
# No caso, este notebook contém um teste para a predição dos casos de COVID-19, baseado em https://www.tensorflow.org/tutorials/structured_data/time_series.

# %% [markdown]
# # 1. Importação das bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from statsmodels.tsa.stattools import pacf
from time import time
from scipy import stats
import math
import os

# %%
# Configura os parâmetros do Matplotlib
# %matplotlib inline

plt.rcParams.update({'font.size': 20, 
                     'figure.figsize': (10, 8),
                     'figure.dpi': 90,
                     'savefig.dpi': 300,
                     'axes.grid': True,
                     'axes.axisbelow': True, 
                     'grid.color': 'k', 
                     'grid.linestyle': ':', 
                     'grid.linewidth': 0.5,
                     'grid.alpha': 0.5})

# %% [markdown]
# # 2. Importação do arquivo de dados

# %%
# Arquivo principal
dataset = pd.read_csv('data/covid19-corrigido.csv')

# %%
# Habilita/Desabilita a opção para exibir todas as linhas
#pd.set_option('display.max_rows', None)

pd.set_option('display.max_columns', None)

# %%
dataset.head()
# Out:
#          Data  País/Região  Latitude  Longitude  PIB 2019   População  \
# 0  2020-01-22  Afghanistan   33.0000    65.0000   18734.0  38928346.0
# 1  2020-01-22      Albania   41.1533    20.1683   15418.0   2877797.0
# 2  2020-01-22      Algeria   28.0339     1.6596  172781.0  43851044.0
# 3  2020-01-22      Andorra   42.5063     1.5218   91527.0     77265.0
# 4  2020-01-22       Angola  -11.2027    17.8739  105902.0  32866272.0
#
#    População Urbana  Área (Km/2)  Densidade (Km/2)  Taxa de Fertilidade  \
# 0              25.0     652860.0              60.0                 4.60
# 1              63.0      27400.0             105.0                 1.60
# 2              73.0    2381740.0              18.0                 3.10
# 3              88.0        470.0             164.0                 1.41
# 4              67.0    1246700.0              26.0                 5.60
#
#    Média de Idade  Taxa de Fumantes  \
# 0            18.0              21.4
# ...

# %%
# Exibe as dimensões dos arquivos
print("Dimensões do arquivo principal:\n")
print(f"Total de linhas: {dataset.shape[0]}")
print(f"Total de colunas: {dataset.shape[1]}")
print()
# Out:
# Dimensões do arquivo principal:
#
# Total de linhas: 15555
# Total de colunas: 17

# %% [markdown]
# # 3. Corrige a coluna dos países

# %%
# Cria uma cópia do arquivo de dados
df = dataset.copy(deep=True)

# %%
df.head()
# Out:
#          Data  País/Região  Latitude  Longitude  PIB 2019   População  \
# 0  2020-01-22  Afghanistan   33.0000    65.0000   18734.0  38928346.0
# 1  2020-01-22      Albania   41.1533    20.1683   15418.0   2877797.0
# 2  2020-01-22      Algeria   28.0339     1.6596  172781.0  43851044.0
# 3  2020-01-22      Andorra   42.5063     1.5218   91527.0     77265.0
# 4  2020-01-22       Angola  -11.2027    17.8739  105902.0  32866272.0
#
#    População Urbana  Área (Km/2)  Densidade (Km/2)  Taxa de Fertilidade  \
# 0              25.0     652860.0              60.0                 4.60
# 1              63.0      27400.0             105.0                 1.60
# 2              73.0    2381740.0              18.0                 3.10
# 3              88.0        470.0             164.0                 1.41
# 4              67.0    1246700.0              26.0                 5.60
#
#    Média de Idade  Taxa de Fumantes  \
# 0            18.0              21.4
# ...

# %%
# Converte o atributo País/Região para valores categóricos
df['País/Região'] = df['País/Região'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15555 entries, 0 to 15554
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Data                                        15555 non-null  object
#  1   País/Região                                 15555 non-null  category
#  2   Latitude                                    15555 non-null  float64
#  3   Longitude                                   15555 non-null  float64
#  4   PIB 2019                                    15555 non-null  float64
#  5   População                                   15555 non-null  float64
#  6   População Urbana                            15555 non-null  float64
#  7   Área (Km/2)                                 15555 non-null  float64
#  8   Densidade (Km/2)                            15555 non-null  float64
# ...

# %%
# Gera uma nova coluna com o código do país
df['Código do País'] = df['País/Região'].cat.codes

# %%
# Define uma nova ordem para as colunas
colunas = [
    'Data',
    'País/Região',
    'Código do País',
    'Latitude',
    'Longitude',
    'PIB 2019',
    'População',
    'População Urbana',
    'Área (Km/2)',
    'Densidade (Km/2)',
    'Taxa de Fertilidade',
    'Média de Idade',
    'Taxa de Fumantes',
    'Taxa de Mortalidade por Doenças Pulmonares',
    'Total de Leitos Hospitalares',
    'Temperatura Média (Janeiro - Março)',
    'Taxa de Umidade (Janeiro - Março)',
    'Casos Confirmados'
]

# %%
# Altera a ordem das colunas
df = df[colunas]

# %%
# Converte as datas para o formato correto
df['Data'] = pd.to_datetime(df['Data'], format='%Y-%m-%d')

# %% [markdown]
# # 4. Separa os features utilizados na predição

# %%
df.head()
# Out:
#         Data  País/Região  Código do País  Latitude  Longitude  PIB 2019  \
# 0 2020-01-22  Afghanistan               0   33.0000    65.0000   18734.0
# 1 2020-01-22      Albania               1   41.1533    20.1683   15418.0
# 2 2020-01-22      Algeria               2   28.0339     1.6596  172781.0
# 3 2020-01-22      Andorra               3   42.5063     1.5218   91527.0
# 4 2020-01-22       Angola               4  -11.2027    17.8739  105902.0
#
#     População  População Urbana  Área (Km/2)  Densidade (Km/2)  \
# 0  38928346.0              25.0     652860.0              60.0
# 1   2877797.0              63.0      27400.0             105.0
# 2  43851044.0              73.0    2381740.0              18.0
# 3     77265.0              88.0        470.0             164.0
# 4  32866272.0              67.0    1246700.0              26.0
#
#    Taxa de Fertilidade  Média de Idade  Taxa de Fumantes  \
# 0                 4.60            18.0              21.4
# ...

# %%
# Lista com os features que serão considerados na predição
lista_features = ['Latitude', 'Longitude', 'PIB 2019', 'População', 'População Urbana', 'Área (Km/2)', 'Densidade (Km/2)', 
                  'Taxa de Fertilidade', 'Média de Idade', 'Taxa de Fumantes', 'Taxa de Mortalidade por Doenças Pulmonares',
                  'Total de Leitos Hospitalares', 'Temperatura Média (Janeiro - Março)', 'Taxa de Umidade (Janeiro - Março)']

# %%
# Lista com os features que serão considerados na predição
lista_features = ['Latitude', 'Longitude', 'PIB 2019', 'População', 'População Urbana', 'Área (Km/2)', 'Densidade (Km/2)', 
                  'Taxa de Fertilidade', 'Média de Idade', 'Taxa de Fumantes', 'Taxa de Mortalidade por Doenças Pulmonares',
                  'Total de Leitos Hospitalares', 'Temperatura Média (Janeiro - Março)', 'Taxa de Umidade (Janeiro - Março)']

# Cria o conjunto de features
features = df[lista_features]
features.index = df['Data']
features.head()
# Out:
#             Latitude  Longitude  PIB 2019   População  População Urbana  \
# Data
# 2020-01-22   33.0000    65.0000   18734.0  38928346.0              25.0
# 2020-01-22   41.1533    20.1683   15418.0   2877797.0              63.0
# 2020-01-22   28.0339     1.6596  172781.0  43851044.0              73.0
# 2020-01-22   42.5063     1.5218   91527.0     77265.0              88.0
# 2020-01-22  -11.2027    17.8739  105902.0  32866272.0              67.0
#
#             Área (Km/2)  Densidade (Km/2)  Taxa de Fertilidade  \
# Data
# 2020-01-22     652860.0              60.0                 4.60
# 2020-01-22      27400.0             105.0                 1.60
# 2020-01-22    2381740.0              18.0                 3.10
# 2020-01-22        470.0             164.0                 1.41
# 2020-01-22    1246700.0              26.0                 5.60
#
#             Média de Idade  Taxa de Fumantes  \
# Data
# 2020-01-22            18.0              21.4
# ...

# %% [markdown]
# # 5. Padroniza o conjunto de dados

# %%
# Total de dados de treinamento
TRAIN_SPLIT = int(len(df) * 0.8)

# Define a semente para garantir a reprodutibilidade
tf.random.set_seed(13)

# %%
# Padroniza os dados, utilizando a média e o desvio padrão dos dados de treinamento
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

# %% [markdown]
# # 6. Modelo de etapa única

# %% [markdown]
# Em um modelo de etapa única, o modelo aprende a prever um único ponto no futuro com base em algum histórico fornecido.
#
# A função abaixo executa a mesma tarefa de janelas como abaixo, no entanto, aqui ela mostra a observação passada com base no tamanho da etapa fornecida.

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size, target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

    if single_step:
        labels.append(target[i+target_size])
    else:
        labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

# %%
past_history = 720
future_target = 72
STEP = 6

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)

x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (120, 14)

# %%
BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-c2a5b17ee656> in <module>()
#       2 BUFFER_SIZE = 10000
#       3
# ----> 4 train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
#       5 train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
#       6
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in from_tensor_slices(tensors)
#     638       Dataset: A `Dataset`.
#     639     """
# --> 640     return TensorSliceDataset(tensors)
#     641
#     642   class _GeneratorState(object):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py in __init__(self, element)
#    2866     for t in self._tensors[1:]:
# ...

# %%
# Teste GeoPandas

import geopandas

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

lat = df['Latitude'].values
long = df['Longitude'].values

gdf = geopandas.GeoDataFrame(df, geometry=geopandas.points_from_xy(df.Longitude, df.Latitude))

ax = world.plot(color='white', edgecolor='black', figsize=[14,12])

gdf.plot(ax=ax, color='red', alpha=0.3);

plt.title("Casos de COVID-19", fontsize=20);

# %%
# Exibe somente os casos confirmados > 0
df1[df1['Casos Confirmados'] > 0].head()
# Out:
#            Data  País/Região   Latitude   Longitude    PIB 2019     População  \
# 36   2020-01-22        China  32.828385  111.649082  14140163.0  1.439324e+09
# 85   2020-01-22        Japan  36.000000  138.000000   5154475.0  1.264765e+08
# 152  2020-01-22  South Korea  36.000000  128.000000   1629532.0  5.126918e+07
# 161  2020-01-22       Taiwan  23.700000  121.000000    586104.0  2.381678e+07
# 163  2020-01-22     Thailand  15.000000  101.000000    529177.0  6.979998e+07
#
#      População Urbana  Área (Km/2)  Densidade (Km/2)  Taxa de Fertilidade  \
# 36               61.0    9388211.0             153.0                  1.7
# 85               92.0     364555.0             347.0                  1.4
# 152              82.0      97230.0             527.0                  1.1
# 161              79.0      35410.0             673.0                  1.2
# 163              51.0     510890.0             137.0                  1.5
#
#      Média de Idade  Taxa de Fumantes  \
# ...

# %%
# Somente China
df1[df1['País/Região'] == 'China'].head()
# Out:
#            Data País/Região   Latitude   Longitude    PIB 2019     População  \
# 36   2020-01-22       China  32.828385  111.649082  14140163.0  1.439324e+09
# 219  2020-01-23       China  32.828385  111.649082  14140163.0  1.439324e+09
# 402  2020-01-24       China  32.828385  111.649082  14140163.0  1.439324e+09
# 585  2020-01-25       China  32.828385  111.649082  14140163.0  1.439324e+09
# 768  2020-01-26       China  32.828385  111.649082  14140163.0  1.439324e+09
#
#      População Urbana  Área (Km/2)  Densidade (Km/2)  Taxa de Fertilidade  \
# 36               61.0    9388211.0             153.0                  1.7
# 219              61.0    9388211.0             153.0                  1.7
# 402              61.0    9388211.0             153.0                  1.7
# 585              61.0    9388211.0             153.0                  1.7
# 768              61.0    9388211.0             153.0                  1.7
#
#      Média de Idade  Taxa de Fumantes  \
# ...

# %%
# Conta o número de casos confirmados para cada país
df1.groupby(['País/Região'])['Casos Confirmados'].sum().sort_values(ascending=False)
# Out:
# País/Região
# United States            7522255
# China                    5429283
# Italy                    3304863
# Spain                    2924367
# Germany                  2252429
# France                   1759183
# Iran                     1481148
# United Kingdom           1118538
# Turkey                    661052
# Switzerland               497217
# Belgium                   444246
# Netherlands               418395
#                           ...
# Nicaragua                    135
# Malawi                       125
# Bhutan                       120
# Gambia                       120
# Sierra Leone                 103
# Burundi                       56
# Western Sahara                52
# Timor-Leste                   43
# Sao Tome and Principe         40
# Papua New Guinea              37
# South Sudan                   33
# Yemen                          6
# Name: Casos Confirmados, Length: 183, dtype: int64

# %%
# Evolução dos casos confirmados
data = df1.groupby(['Data']).agg({'Casos Confirmados': np.sum}).sort_values(by ='Data', ascending=True)

data.plot(figsize=(20,10), marker='o', markersize=10, linewidth=2, fontsize=14)
plt.xlabel('Data', fontsize=20);

# %%
# Define as colunas
colunas = ['PIB 2019', 'População', 'População Urbana', 'Área (Km/2)','Densidade (Km/2)', 'Taxa de Fertilidade', 'Média de Idade', 
           'Taxa de Fumantes', 'Taxa de Mortalidade por Doenças Pulmonares', 'Total de Leitos Hospitalares',
           'Temperatura Média (Janeiro - Março)', 'Taxa de Umidade (Janeiro - Março)', 'Casos Confirmados']

# Calcula a matriz de correlação
correlations = df1[colunas].corr()

# Mapa de cor
cmap = sns.diverging_palette(250, 10, as_cmap=True)
#cmap = 'coolwarm'

plt.figure(figsize=(18, 15))

# Plotagem, utilizando o SEABORN
sns.heatmap(correlations, cmap=cmap, 
            xticklabels=correlations.columns, yticklabels=correlations.columns, 
            #xticklabels=False, yticklabels=correlations.columns, 
            cbar=True,
            annot=True, annot_kws={'size': 13});

# Título
plt.suptitle('Matriz de Correlação', x=0.54, y=1.02, fontsize=30);

# Ajusta os labels
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(fontsize=14)

# Ajusta o layout
plt.tight_layout();

# Salva a figura
#plt.savefig('imagens/covid_australia.png', dpi=300, transparent=True, bbox_inches='tight');

# %%
# Exibe os dados do Brasil
# Os dados já estão ordenados
df1[df1['País/Região'] == 'Brazil'][['Data', 'País/Região', 'Casos Confirmados']]
# Out:
#              Data País/Região  Casos Confirmados
# 23     2020-01-22      Brazil                  0
# 206    2020-01-23      Brazil                  0
# 389    2020-01-24      Brazil                  0
# 572    2020-01-25      Brazil                  0
# 755    2020-01-26      Brazil                  0
# 938    2020-01-27      Brazil                  0
# 1121   2020-01-28      Brazil                  0
# 1304   2020-01-29      Brazil                  0
# 1487   2020-01-30      Brazil                  0
# ...           ...         ...                ...
# 13931  2020-04-07      Brazil              14034
# 14114  2020-04-08      Brazil              16170
# 14297  2020-04-09      Brazil              18092
# 14480  2020-04-10      Brazil              19638
# 14663  2020-04-11      Brazil              20727
# 14846  2020-04-12      Brazil              22192
# 15029  2020-04-13      Brazil              23430
# 15212  2020-04-14      Brazil              25262
# ...

# %%
# Evolução dos casos confirmados - Brasil
plt.figure(figsize=(10, 5))

# País
pais = 'Brazil'

# Dados -> Brasil
valores = df1[df1['País/Região'] == pais]

# Converte para o formato de data
valores['Data'] = pd.to_datetime(valores['Data'])

plt.plot(valores['Data'], valores['Casos Confirmados'], marker='o', markersize=5, linewidth=1)

# Título
plt.suptitle('Casos Confirmados - ' + pais, y=1.05, fontsize=30);

plt.ylabel('Total de Casos', fontsize=20)

# Ajusta os labels
plt.xticks(rotation=45, ha='right', fontsize=14)
plt.yticks(fontsize=14)


# Ajusta o layout
plt.tight_layout();
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
def univariate_data(dataset, start_index, end_index, history_size, target_size):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i)
    # Reshape data from (history_size,) to (history_size, 1)
    data.append(np.reshape(dataset[indices], (history_size, 1)))
    labels.append(dataset[i+target_size])
  return np.array(data), np.array(labels)

# %%
TRAIN_SPLIT = int(len(df) * 0.8)

# %%
tf.random.set_seed(13)

# %%
uni_data = df['Casos Confirmados']
uni_data.index = df['Data']
uni_data.head()
# Out:
# Data
# 2020-01-22    0
# 2020-01-22    0
# 2020-01-22    0
# 2020-01-22    0
# 2020-01-22    0
# Name: Casos Confirmados, dtype: int64

# %%
uni_data.plot(subplots=True);

# %%
uni_data = uni_data.values

# %%
uni_train_mean = uni_data[:TRAIN_SPLIT].mean()
uni_train_std = uni_data[:TRAIN_SPLIT].std()

# %%
uni_data = (uni_data-uni_train_mean)/uni_train_std

# %%
univariate_past_history = 20
univariate_future_target = 0

x_train_uni, y_train_uni = univariate_data(uni_data, 0, TRAIN_SPLIT,
                                           univariate_past_history,
                                           univariate_future_target)

x_val_uni, y_val_uni = univariate_data(uni_data, TRAIN_SPLIT, None,
                                       univariate_past_history,
                                       univariate_future_target)

# %%
print ('Single window of past history')
print (x_train_uni[0])

print ('\n Target cases to predict')
print (y_train_uni[0])
# Out:
# Single window of past history
# [[-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]
#  [-0.11491196]]
#
#  Target cases to predict
# -0.11491196012528145

# %%
def create_time_steps(length):
  return list(range(-length, 0))

# %%
def show_plot(plot_data, delta, title):
  labels = ['History', 'True Future', 'Model Prediction']
  marker = ['.-', 'rx', 'go']
  time_steps = create_time_steps(plot_data[0].shape[0])
  if delta:
    future = delta
  else:
    future = 0

  plt.title(title)
  for i, x in enumerate(plot_data):
    if i:
      plt.plot(future, plot_data[i], marker[i], markersize=10,
               label=labels[i])
    else:
      plt.plot(time_steps, plot_data[i].flatten(), marker[i], label=labels[i])
  plt.legend()
  plt.xlim([time_steps[0], (future+5)*2])
  plt.xlabel('Time-Step')
  return plt

# %%
show_plot([x_train_uni[0], y_train_uni[0]], 0, 'Sample Example');

# %%
def baseline(history):
  return np.mean(history)

# %%
show_plot([x_train_uni[0], y_train_uni[0], baseline(x_train_uni[0])], 0,
           'Baseline Prediction Example');

# %%
BATCH_SIZE = 256
BUFFER_SIZE = 10000

train_univariate = tf.data.Dataset.from_tensor_slices((x_train_uni, y_train_uni))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_univariate = tf.data.Dataset.from_tensor_slices((x_val_uni, y_val_uni))
val_univariate = val_univariate.batch(BATCH_SIZE).repeat()

# %%
simple_lstm_model = tf.keras.models.Sequential([
    tf.keras.layers.LSTM(8, input_shape=x_train_uni.shape[-2:]),
    tf.keras.layers.Dense(1)
])

simple_lstm_model.compile(optimizer='adam', loss='mae')

# %%
for x, y in val_univariate.take(1):
    print(simple_lstm_model.predict(x).shape)
# Out:
# (256, 1)

# %%
EVALUATION_INTERVAL = 200
EPOCHS = 10

simple_lstm_model.fit(train_univariate, epochs=EPOCHS,
                      steps_per_epoch=EVALUATION_INTERVAL,
                      validation_data=val_univariate, validation_steps=50)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 5s 26ms/step - loss: 0.1210 - val_loss: 1.2208
# Epoch 2/10
# 200/200 [==============================] - 4s 20ms/step - loss: 0.1150 - val_loss: 1.2230
# Epoch 3/10
# 200/200 [==============================] - 5s 24ms/step - loss: 0.1146 - val_loss: 1.2224
# Epoch 4/10
# 200/200 [==============================] - 7s 33ms/step - loss: 0.1150 - val_loss: 1.2225
# Epoch 5/10
# 200/200 [==============================] - 5s 23ms/step - loss: 0.1176 - val_loss: 1.2232
# Epoch 6/10
# 200/200 [==============================] - 7s 33ms/step - loss: 0.1131 - val_loss: 1.2226
# Epoch 7/10
# 200/200 [==============================] - 6s 28ms/step - loss: 0.1187 - val_loss: 1.2228
# Epoch 8/10
# 200/200 [==============================] - 6s 29ms/step - loss: 0.1132 - val_loss: 1.2227
# Epoch 9/10
# 200/200 [==============================] - 6s 31ms/step - loss: 0.1158 - val_loss: 1.2228
# Epoch 10/10
# ...

# %%
for x, y in val_univariate.take(3):
  plot = show_plot([x[0].numpy(), y[0].numpy(),
                    simple_lstm_model.predict(x)[0]], 0, 'Simple LSTM model')
  plot.show()

# %%
# Lista com os features que serão considerados na predição
lista_features = ['Latitude', 'Longitude', 'PIB 2019', 'População', 'População Urbana', 'Área (Km/2)', 'Densidade (Km/2)', 
                  'Taxa de Fertilidade', 'Média de Idade', 'Taxa de Fumantes', 'Taxa de Mortalidade por Doenças Pulmonares',
                  'Total de Leitos Hospitalares', 'Temperatura Média (Janeiro - Março)', 'Taxa de Umidade (Janeiro - Março)']

# Cria o conjunto de features
features = df[lista_features]
features.index = df['Data']
features.head()
# Out:
#             Latitude  Longitude  PIB 2019   População  População Urbana  \
# Data
# 2020-01-22   33.0000    65.0000   18734.0  38928346.0              25.0
# 2020-01-22   41.1533    20.1683   15418.0   2877797.0              63.0
# 2020-01-22   28.0339     1.6596  172781.0  43851044.0              73.0
# 2020-01-22   42.5063     1.5218   91527.0     77265.0              88.0
# 2020-01-22  -11.2027    17.8739  105902.0  32866272.0              67.0
#
#             Área (Km/2)  Densidade (Km/2)  Taxa de Fertilidade  \
# Data
# 2020-01-22     652860.0              60.0                 4.60
# 2020-01-22      27400.0             105.0                 1.60
# 2020-01-22    2381740.0              18.0                 3.10
# 2020-01-22        470.0             164.0                 1.41
# 2020-01-22    1246700.0              26.0                 5.60
#
#             Média de Idade  Taxa de Fumantes  \
# Data
# 2020-01-22            18.0              21.4
# ...

# %%
dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)

# %%
dataset = (dataset-data_mean)/data_std

# %%
def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
  data = []
  labels = []

  start_index = start_index + history_size
  if end_index is None:
    end_index = len(dataset) - target_size

  for i in range(start_index, end_index):
    indices = range(i-history_size, i, step)
    data.append(dataset[indices])

    if single_step:
      labels.append(target[i+target_size])
    else:
      labels.append(target[i:i+target_size])

  return np.array(data), np.array(labels)

# %%
past_history = 720
future_target = 72
STEP = 6

x_train_single, y_train_single = multivariate_data(dataset, dataset[:, 1], 0,
                                                   TRAIN_SPLIT, past_history,
                                                   future_target, STEP,
                                                   single_step=True)
x_val_single, y_val_single = multivariate_data(dataset, dataset[:, 1],
                                               TRAIN_SPLIT, None, past_history,
                                               future_target, STEP,
                                               single_step=True)

# %%
print ('Single window of past history : {}'.format(x_train_single[0].shape))
# Out:
# Single window of past history : (120, 14)

# %%
train_data_single = tf.data.Dataset.from_tensor_slices((x_train_single, y_train_single))
train_data_single = train_data_single.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_single = tf.data.Dataset.from_tensor_slices((x_val_single, y_val_single))
val_data_single = val_data_single.batch(BATCH_SIZE).repeat()

# %%
single_step_model = tf.keras.models.Sequential()
single_step_model.add(tf.keras.layers.LSTM(32,
                                           input_shape=x_train_single.shape[-2:]))
single_step_model.add(tf.keras.layers.Dense(1))

single_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mae')

# %%
for x, y in val_data_single.take(1):
  print(single_step_model.predict(x).shape)
# Out:
# (256, 1)

# %%
single_step_history = single_step_model.fit(train_data_single, epochs=EPOCHS,
                                            steps_per_epoch=EVALUATION_INTERVAL,
                                            validation_data=val_data_single,
                                            validation_steps=50)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 55s 273ms/step - loss: 0.5903 - val_loss: 0.4809
# Epoch 2/10
# 200/200 [==============================] - 52s 259ms/step - loss: 0.4041 - val_loss: 0.3344
# Epoch 3/10
# 200/200 [==============================] - 60s 302ms/step - loss: 0.2879 - val_loss: 0.2463
# Epoch 4/10
# 200/200 [==============================] - 48s 240ms/step - loss: 0.2038 - val_loss: 0.1702
# Epoch 5/10
# 200/200 [==============================] - 45s 223ms/step - loss: 0.1400 - val_loss: 0.1122
# Epoch 6/10
# 200/200 [==============================] - 56s 282ms/step - loss: 0.0939 - val_loss: 0.0709
# Epoch 7/10
# 200/200 [==============================] - 62s 309ms/step - loss: 0.0613 - val_loss: 0.0548
# Epoch 8/10
# 200/200 [==============================] - 42s 211ms/step - loss: 0.0472 - val_loss: 0.0430
# Epoch 9/10
# 200/200 [==============================] - 36s 180ms/step - loss: 0.0396 - val_loss: 0.0366
# Epoch 10/10
# ...

# %%
def plot_train_history(history, title):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs = range(len(loss))

  plt.figure()

  plt.plot(epochs, loss, 'b', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title(title)
  plt.legend()

  plt.show()

# %%
plot_train_history(single_step_history,
                   'Single Step Training and validation loss')

# %%
for x, y in val_data_single.take(3):
  plot = show_plot([x[0][:, 1].numpy(), y[0].numpy(),
                    single_step_model.predict(x)[0]], 12,
                   'Single Step Prediction')
  plot.show()

# %%
future_target = 72
x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 1], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 1],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

# %%
print ('Single window of past history : {}'.format(x_train_multi[0].shape))
print ('\n Target case to predict : {}'.format(y_train_multi[0].shape))
# Out:
# Single window of past history : (120, 14)
#
#  Target case to predict : (72,)

# %%
train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

# %%
def multi_step_plot(history, true_future, prediction):
  plt.figure(figsize=(12, 6))
  num_in = create_time_steps(len(history))
  num_out = len(true_future)

  plt.plot(num_in, np.array(history[:, 1]), label='History')
  plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
           label='True Future')
  if prediction.any():
    plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
             label='Predicted Future')
  plt.legend(loc='upper left')
  plt.show()

# %%
for x, y in train_data_multi.take(1):
  multi_step_plot(x[0], y[0], np.array([0]))

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.LSTM(16, activation='relu'))
multi_step_model.add(tf.keras.layers.Dense(72))

multi_step_model.compile(optimizer=tf.keras.optimizers.RMSprop(clipvalue=1.0), loss='mae')

# %%
for x, y in val_data_multi.take(1):
  print (multi_step_model.predict(x).shape)
# Out:
# (256, 72)

# %%
multi_step_history = multi_step_model.fit(train_data_multi, epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=val_data_multi,
                                          validation_steps=50)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 76s 380ms/step - loss: 0.7246 - val_loss: 0.7077
# Epoch 2/10
# 200/200 [==============================] - 69s 347ms/step - loss: 0.6952 - val_loss: 0.6852
# Epoch 3/10
# 200/200 [==============================] - 66s 331ms/step - loss: 0.6763 - val_loss: 0.6684
# Epoch 4/10
# 200/200 [==============================] - 64s 321ms/step - loss: 0.6625 - val_loss: 0.6573
# Epoch 5/10
# 200/200 [==============================] - 63s 313ms/step - loss: 0.6525 - val_loss: 0.6477
# Epoch 6/10
# 200/200 [==============================] - 64s 318ms/step - loss: 0.6448 - val_loss: 0.6411
# Epoch 7/10
# 200/200 [==============================] - 64s 318ms/step - loss: 0.6383 - val_loss: 0.6351
# Epoch 8/10
# 200/200 [==============================] - 64s 320ms/step - loss: 0.6321 - val_loss: 0.6293
# Epoch 9/10
# 200/200 [==============================] - 63s 314ms/step - loss: 0.6263 - val_loss: 0.6234
# Epoch 10/10
# ...

# %%
for x, y in val_data_multi.take(3):
  multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
